# %% [markdown]
# Load selected configs
#
#
# Ablation study:
# avec/sans SNV ;
# SG smoothing vs SG derivative ;
# random vs center balanced pixels ;
# règles SIMCA ;
# nombre de composantes ;
# seuil objet ;
# bordures activées/désactivées.
#
#
# Random-state stability:
# seeds multiples ;
# variation des résultats ;
# stabilité de balanced_pixels=random.
#
#
# Sensitivity to mixture truth:
# position_dilation_radius = 0, 1, 2, 3, 5;
# effet sur FP/FN ;
# effet sur objets incertains.
#
#
# Sensitivity to border width:
# border_width = 0, 1, 2, 3, 4;
# effet sur erreurs ;
# effet sur nombre de pixels utilisés.
#
#
# Optuna comparison:
# comparer Optuna vs grid search ;
# vérifier si Optuna retrouve les mêmes régions d’hyperparamètres.
#
#
# Conclusion robustness:
# quels choix sont stables ;
# quels choix sont sensibles ;
# quelles conclusions sont robustes.
#
#
# Sorties attendues:
# results/robustness/ablation_summary.csv
# results/robustness/random_seed_stability.csv
# results/robustness/border_sensitivity.csv
# results/robustness/truth_radius_sensitivity.csv
# results/robustness/optuna_trials.csv

# %%
from src.workflows.simca_cv_calibration import run_simca_empirical_rule_grid
from src.workflows.simca_optuna import run_optuna_simca_pixel_optimization
from src.decision.border import border_width_object_threshold_grid
from src.decision.metrics import metrics_by_group
from src.visualization.plot_generic import ...
