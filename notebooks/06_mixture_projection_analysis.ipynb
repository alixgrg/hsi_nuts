# %% [markdown]
# Load final model/config:
# modèle sélectionné dans 05.
#
#
# Project mixture images:
# toutes les images mixtures ;
# pixel-level predictions.
# Build mixture truth
# via images de position ;
# position_dilation_radius;
# truth_available.
#
#
# Object-level aggregation:
# seuil objet choisi ;
# core pixels / border exclusion ;
# three-way decision.
#
#
# Per-image analysis:
# nombre d’objets par image ;
# proportion peanut prédite ;
# erreurs FP/FN si vérité disponible ;
# objets incertains.
#
#
# Visual maps:
# cartes de prédiction ;
# cartes d’erreurs ;
# FP/FN overlays ;
# cartes par image mixture.
#
#
# Conclusion mixtures:
# comportement général ;
# images difficiles ;
# effet des bordures ;
# cas incertains.
#
#
# Sorties attendues:
# results/mixtures/mixture_pixel_predictions.parquet
# results/mixtures/mixture_object_predictions.csv
# results/mixtures/mixture_image_summary.csv

# %%
from src.workflows.simca_pixel_grid import refit_best_grid_row
from src.decision.truth import add_pixel_truth_labels
from src.decision.aggregation import aggregate_pixel_predictions_to_objects
from src.decision.border import aggregate_pixel_predictions_to_objects_core
from src.decision.uncertainty import add_three_way_object_decision
from src.decision.maps import make_pixel_error_map
from src.visualization.plot_decision import ...
from src.visualization.plot_images import ...
