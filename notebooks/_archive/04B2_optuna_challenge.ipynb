# %% [markdown]
# # 04B2 — Optuna Bayesian/Pareto challengers
#
# Objectif : générer des modèles challengers avec Optuna, puis les comparer au panel robuste issu de 04B.
#
# Protocole :
# - calibration SIMCA : objets purs peanut batches 1–2 ;
# - validation : objets purs almond + peanut batch 3 ;
# - aucune image mixture ;
# - aucun batch 4 ;
# - études Optuna séparées pour `object_matrix` et `pixel_matrix` ;
# - Optuna ne remplace pas la grille : il propose des challengers ;
# - la sélection finale reste Pareto, sans score unique.
#
# Différence avec 04B :
# - 04B sélectionne un panel robuste depuis la grille exhaustive ;
# - 04B2 cherche des configurations supplémentaires avec Optuna ;
# - les candidats Optuna sont refittés, calibrés en 3-way sur validation, puis fusionnés avec le panel 04B pour le test externe 04C.
#
# Sorties principales :
# - `optuna_trials_object_matrix.parquet`
# - `optuna_trials_pixel_matrix.parquet`
# - `optuna_pareto_candidates.parquet`
# - `optuna_validation_refit_metrics.parquet`
# - `optuna_validation_3way_metrics.parquet`
# - `optuna_challengers_for_04C.parquet`
# - `candidate_configs_for_pure_test.parquet`

# %%
from __future__ import annotations

import sys
import json
import gc
import optuna
from pathlib import Path

import numpy as np
import pandas as pd
from IPython.display import display

pd.set_option("display.max_columns", 240)
pd.set_option("display.max_rows", 300)

CURRENT_DIR = Path.cwd().resolve()

if (CURRENT_DIR / "src").exists():
    PROJECT_ROOT = CURRENT_DIR
elif (CURRENT_DIR.parent / "src").exists():
    PROJECT_ROOT = CURRENT_DIR.parent
else:
    raise RuntimeError(
        "Could not find project root. Run this notebook from the project root or notebooks/."
    )

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print("PROJECT_ROOT:", PROJECT_ROOT)

from src.io.database_h5 import load_nir_uco_h5
from src import experiment_config as expcfg

from src.utils import (
    save_parquet,
    save_parquet_if_nonempty,
    load_parquet,
    list_result_files,
)

from src.spectra.band_selection import (
    select_wavelength_range_from_database,
    wavelength_selection_summary,
)

from src.decision.metrics import (
    add_binary_confusion_case,
)

from src.decision.uncertainty import (
    evaluate_three_way_by_config,
    calibrate_three_way_thresholds_by_config,
)

from src.workflows.simca import (
    make_target_train_filters,
    refit_selected_simca_configs,
)

from src.workflows.simca_selection_utils import (
    ensure_candidate_columns,
    normalize_simca_rule_columns,
    add_detection_selection_score,
    add_reference_selection_scores,
    fill_selected_config_defaults,
    summarize_metric_stability,
    pareto_front_by_group,
    materialize_selection_metrics,
)

from src.workflows.simca_candidates import (
    build_pca_preprocessing_configs_by_matrix_family,
    deduplicate_simca_candidates,
    filter_simca_candidates_by_pca_preprocessing,
)

from src.workflows.simca_optuna import (
    make_optuna_binary_pareto_objective,
    optuna_trials_dataframe,
    close_optuna_study,
)

from src.visualization.plot_model_selection import (
    plot_detection_pareto,
    plot_three_way_tradeoff,
)

# %load_ext autoreload
# %autoreload 2
# Out:
# PROJECT_ROOT: C:\Users\alixg\OneDrive - Université Paris-Dauphine\hsi_nuts

# %%
# ---------------------------------------------------------------------
# Paths
# ---------------------------------------------------------------------
DB_H5_PATH = PROJECT_ROOT / "HSI Data" / "processed" / "nir_uco_database.h5"

# ---------------------------------------------------------------------
# Spectral configuration
# ---------------------------------------------------------------------
USE_WAVELENGTH_WINDOW = False
WAVELENGTH_MODE = expcfg.DEFAULT_WAVELENGTH_MODE

WINDOW_MIN_NM = 1225.0
WINDOW_MAX_NM = 1675.0

if USE_WAVELENGTH_WINDOW:
    RESULTS_TAG = f"{int(WINDOW_MIN_NM)}_{int(WINDOW_MAX_NM)}"
else:
    RESULTS_TAG = expcfg.DEFAULT_RESULTS_TAG

# ---------------------------------------------------------------------
# Inputs
# ---------------------------------------------------------------------
RESULTS_03_DIR = PROJECT_ROOT / "results" / f"03_pca_{RESULTS_TAG}"
PCA_SELECTED_PREPROCESSINGS_PATH = RESULTS_03_DIR / "pca_selected_preprocessings.parquet"

RESULTS_04A_DIR = PROJECT_ROOT / "results" / f"04A_simca_grid_validation_{RESULTS_TAG}"
GRID_SELECTED_CANDIDATES_PATH = RESULTS_04A_DIR / "selected_candidate_configs.parquet"

RESULTS_04B_DIR = PROJECT_ROOT / "results" / f"04B_simca_validation_robustness_{RESULTS_TAG}"
ROBUST_CANDIDATE_CONFIGS_PATH = RESULTS_04B_DIR / "04B_final_candidate_panel.parquet"

# ---------------------------------------------------------------------
# Outputs
# ---------------------------------------------------------------------
RESULTS_DIR = PROJECT_ROOT / "results" / f"04B2_optuna_challenge_{RESULTS_TAG}"
STUDY_DIR = RESULTS_DIR / "optuna_studies"

RESULTS_DIR.mkdir(parents=True, exist_ok=True)
STUDY_DIR.mkdir(parents=True, exist_ok=True)

OPTUNA_STORAGE_OBJECT_PATH = STUDY_DIR / f"simca_optuna_object_matrix_{RESULTS_TAG}.db"
OPTUNA_STORAGE_PIXEL_PATH = STUDY_DIR / f"simca_optuna_pixel_matrix_{RESULTS_TAG}.db"

OPTUNA_TRIALS_OBJECT_PATH = RESULTS_DIR / "optuna_trials_object_matrix.parquet"
OPTUNA_TRIALS_PIXEL_PATH = RESULTS_DIR / "optuna_trials_pixel_matrix.parquet"

OPTUNA_COMPLETED_TRIALS_OBJECT_PATH = RESULTS_DIR / "optuna_completed_trials_object_matrix.parquet"
OPTUNA_COMPLETED_TRIALS_PIXEL_PATH = RESULTS_DIR / "optuna_completed_trials_pixel_matrix.parquet"

OPTUNA_ALL_TRIALS_PATH = RESULTS_DIR / "optuna_trials_all_families.parquet"
OPTUNA_PARETO_CANDIDATES_PATH = RESULTS_DIR / "optuna_pareto_candidates.parquet"

OPTUNA_VALIDATION_REFIT_OBJECTS_PATH = RESULTS_DIR / "optuna_validation_refit_objects.parquet"
OPTUNA_VALIDATION_REFIT_PIXELS_PATH = RESULTS_DIR / "optuna_validation_refit_pixels.parquet"

OPTUNA_THREE_WAY_GRID_PATH = RESULTS_DIR / "optuna_three_way_threshold_grid.parquet"
OPTUNA_THREE_WAY_SELECTED_PATH = RESULTS_DIR / "optuna_three_way_selected_thresholds.parquet"
OPTUNA_VALIDATION_3WAY_OBJECTS_PATH = RESULTS_DIR / "optuna_validation_3way_objects.parquet"
OPTUNA_VALIDATION_3WAY_METRICS_PATH = RESULTS_DIR / "optuna_validation_3way_metrics.parquet"

OPTUNA_CHALLENGERS_FOR_04C_PATH = RESULTS_DIR / "optuna_challengers_for_04C.parquet"

OPTUNA_VALIDATION_REFIT_METRICS_PATH = RESULTS_DIR / "optuna_validation_refit_metrics.parquet"
OPTUNA_VALIDATION_PIXEL_ERRORS_BY_IMAGE_PATH = RESULTS_DIR / "optuna_validation_pixel_errors_by_image.parquet"
OPTUNA_VALIDATION_REFIT_ERRORS_PATH = RESULTS_DIR / "optuna_validation_refit_errors.parquet"

CANDIDATE_CONFIGS_FOR_PURE_TEST_PATH = RESULTS_DIR / "candidate_configs_for_pure_test.parquet"
OPTUNA_CHALLENGE_PROTOCOL_PATH = RESULTS_DIR / "optuna_challenge_protocol.parquet"

# ---------------------------------------------------------------------
# Protocol
# ---------------------------------------------------------------------
TARGET_CLASS = expcfg.TARGET_CLASS
NON_TARGET_LABEL = expcfg.NON_TARGET_LABEL
REFERENCE_CLASSES = expcfg.REFERENCE_CLASSES

TRAIN_FILTERS = make_target_train_filters(
    target_class=TARGET_CLASS,
    train_batches=expcfg.SIMCA_TRAIN_BATCHES,
)

VALIDATION_FILTERS = {
    "sample_kind": ["pure"],
    "object_nut_type": list(REFERENCE_CLASSES),
    "batch": list(expcfg.SIMCA_VALIDATION_BATCHES),
}

# ---------------------------------------------------------------------
# Optuna search spaces by matrix family
# ---------------------------------------------------------------------

OPTUNA_MATRIX_FAMILY_SPACES = {
    "object_matrix": {
        "matrix_methods": ["object_mean", "object_median"],
        "storage_path": OPTUNA_STORAGE_OBJECT_PATH,
        "trials_path": OPTUNA_TRIALS_OBJECT_PATH,
        "completed_trials_path": OPTUNA_COMPLETED_TRIALS_OBJECT_PATH,
        "study_name": f"simca_optuna_object_matrix_{RESULTS_TAG}",
    },
    "pixel_matrix": {
        "matrix_methods": ["balanced_pixels"],
        "storage_path": OPTUNA_STORAGE_PIXEL_PATH,
        "trials_path": OPTUNA_TRIALS_PIXEL_PATH,
        "completed_trials_path": OPTUNA_COMPLETED_TRIALS_PIXEL_PATH,
        "study_name": f"simca_optuna_pixel_matrix_{RESULTS_TAG}",
    },
}

OPTUNA_RULE_VARIANTS = [
    "simple_chi2",
    "simple_emp_cv",
    "alternative_chi2_fixed2",
    "alternative_chi2_emp_cv",
    "alternative_empHQ_fixed2",
    "alternative_empHQ_emp_cv",
    "data_driven_chi2",
    "data_driven_emp_cv",
    "combined_index_chi2",
]

OPTUNA_N_COMPONENTS_CHOICES = [3, 4, 5, 6, 7, 8, 10, 11, 12]
OPTUNA_ALPHA_CHOICES = list(expcfg.SIMCA_ALPHA_VALUES)

# Object threshold is calibrated inside the objective, not suggested by Optuna.
OPTUNA_OBJECT_THRESHOLDS = list(expcfg.SIMCA_OBJECT_THRESHOLDS)

OPTUNA_M_CHOICES = [20, 40, 60, 80]
OPTUNA_BALANCED_PIXEL_STRATEGY_CHOICES = list(expcfg.BALANCED_PIXEL_STRATEGIES)

OPTUNA_SG_WINDOW_CHOICES = [7, 9, 11, 13, 15]
OPTUNA_SG_POLYORDER_CHOICES = [2]

OPTUNA_POSITION_DILATION_RADIUS_CHOICES = [2, 3, 4, 5]

# ---------------------------------------------------------------------
# Runtime
# ---------------------------------------------------------------------
RUN_OPTUNA = True
LOAD_EXISTING_STUDY = False

OPTUNA_N_TRIALS_PER_FAMILY = {
    "object_matrix": 200,
    "pixel_matrix": 300,
}

OPTUNA_OBJECTIVE_SEEDS = [0, 1, 2]
OPTUNA_MAX_FN_RATE_FOR_THRESHOLD = 0.00
OPTUNA_MAX_FP_RATE_FOR_THRESHOLD = 0.50

N_OPTUNA_PARETO_PER_FAMILY = 25
N_OPTUNA_REFIT_PER_FAMILY = 15

OPTUNA_TIMEOUT = None
OPTUNA_N_JOBS = 1

RANDOM_STATE = expcfg.RANDOM_STATE
REPLACE_BALANCED_PIXELS = expcfg.REPLACE_BALANCED_PIXELS

CV_N_SPLITS = expcfg.CV_N_SPLITS
CV_GROUP_COL = expcfg.CV_GROUP_COL

# Candidate selection from Optuna trials.
N_OPTUNA_CANDIDATES_PER_FAMILY = 8
N_OPTUNA_CANDIDATES_OVERALL = 20

# Merge with 04B robust grid candidates for 04C.
INCLUDE_GRID_ROBUST_CANDIDATES = True
N_GRID_CANDIDATES_TO_KEEP = 25

THREE_WAY_LOWER_THRESHOLDS = np.round(np.arange(0.05, 0.61, 0.05), 2)
THREE_WAY_UPPER_THRESHOLDS = np.round(np.arange(0.50, 0.96, 0.05), 2)
MAX_THREE_WAY_TARGET_MISS_RATE = 0.00
MAX_THREE_WAY_FALSE_ACCEPT_RATE = 0.30
MAX_THREE_WAY_UNCERTAIN_RATE = 0.60

print("DB_H5_PATH:", DB_H5_PATH)
print("RESULTS_DIR:", RESULTS_DIR)
print("TRAIN_FILTERS:", TRAIN_FILTERS)
print("VALIDATION_FILTERS:", VALIDATION_FILTERS)
print("PCA_SELECTED_PREPROCESSINGS_PATH:", PCA_SELECTED_PREPROCESSINGS_PATH)
print("ROBUST_CANDIDATE_CONFIGS_PATH:", ROBUST_CANDIDATE_CONFIGS_PATH)
# Out:
# DB_H5_PATH: C:\Users\alixg\OneDrive - Université Paris-Dauphine\hsi_nuts\HSI Data\processed\nir_uco_database.h5
# RESULTS_DIR: C:\Users\alixg\OneDrive - Université Paris-Dauphine\hsi_nuts\results\04B2_optuna_challenge_non_noisy_all
# TRAIN_FILTERS: {'sample_kind': ['pure'], 'object_nut_type': ['peanut'], 'batch': [1, 2]}
# VALIDATION_FILTERS: {'sample_kind': ['pure'], 'object_nut_type': ['almond', 'peanut'], 'batch': [3]}
# PCA_SELECTED_PREPROCESSINGS_PATH: C:\Users\alixg\OneDrive - Université Paris-Dauphine\hsi_nuts\results\03_pca_non_noisy_all\pca_selected_preprocessings.parquet
# ROBUST_CANDIDATE_CONFIGS_PATH: C:\Users\alixg\OneDrive - Université Paris-Dauphine\hsi_nuts\results\04B_simca_validation_robustness_non_noisy_all\04B_final_candidate_panel.parquet

# %%
if not DB_H5_PATH.exists():
    raise FileNotFoundError(f"Database not found: {DB_H5_PATH}. Run notebook 00 first.")

object_db, image_db = load_nir_uco_h5(
    DB_H5_PATH,
    reconstruct_heavy_object_arrays=True,
)

if USE_WAVELENGTH_WINDOW:
    object_db, image_db, wavelengths, wavelength_info = select_wavelength_range_from_database(
        object_db=object_db,
        image_db=image_db,
        min_nm=WINDOW_MIN_NM,
        max_nm=WINDOW_MAX_NM,
    )
    wavelength_selection_df = wavelength_selection_summary(wavelength_info)
else:
    first_obj = next(iter(object_db.values()))
    wavelengths = first_obj.get("wavelengths")
    wavelengths = np.asarray(wavelengths, dtype=float) if wavelengths is not None else None
    wavelength_selection_df = pd.DataFrame()

if wavelengths is None:
    raise RuntimeError("No wavelength axis found in object_db.")

wavelength_config_df = pd.DataFrame([{
    "wavelength_mode": WAVELENGTH_MODE,
    "use_wavelength_window": bool(USE_WAVELENGTH_WINDOW),
    "results_tag": RESULTS_TAG,
    "window_min_nm": WINDOW_MIN_NM if USE_WAVELENGTH_WINDOW else np.nan,
    "window_max_nm": WINDOW_MAX_NM if USE_WAVELENGTH_WINDOW else np.nan,
    "n_bands": int(len(wavelengths)),
    "min_wavelength_nm": float(np.min(wavelengths)),
    "max_wavelength_nm": float(np.max(wavelengths)),
}])

print("Database loaded")
print("n objects:", len(object_db))
print("n images:", len(image_db))
display(wavelength_config_df)

if PCA_SELECTED_PREPROCESSINGS_PATH.exists():
    pca_selected_preprocessings_df = load_parquet(PCA_SELECTED_PREPROCESSINGS_PATH)
else:
    pca_selected_preprocessings_df = pd.DataFrame()

if GRID_SELECTED_CANDIDATES_PATH.exists():
    grid_selected_candidates_df = load_parquet(GRID_SELECTED_CANDIDATES_PATH)
else:
    grid_selected_candidates_df = pd.DataFrame()

if ROBUST_CANDIDATE_CONFIGS_PATH.exists():
    robust_grid_candidates_df = load_parquet(ROBUST_CANDIDATE_CONFIGS_PATH)
else:
    robust_grid_candidates_df = pd.DataFrame()

if len(robust_grid_candidates_df) == 0:
    raise FileNotFoundError(
        f"No robust 04B candidate panel found at: {ROBUST_CANDIDATE_CONFIGS_PATH}. "
        "Run 04B first."
    )

robust_grid_candidates_df = ensure_candidate_columns(robust_grid_candidates_df)
robust_grid_candidates_df = normalize_simca_rule_columns(robust_grid_candidates_df)
robust_grid_candidates_df = fill_selected_config_defaults(
    robust_grid_candidates_df,
    default_values={
        "target_class": TARGET_CLASS,
        "non_target_label": NON_TARGET_LABEL,
        "sg_window_length": 11,
        "sg_polyorder": 2,
        "position_dilation_radius": 3,
        "m": 40,
        "alpha": 0.05,
        "object_threshold": 0.75,
    },
)

print("PCA selected preprocessings:", pca_selected_preprocessings_df.shape)
print("04A grid candidates:", grid_selected_candidates_df.shape)
print("04B final candidate panel:", robust_grid_candidates_df.shape)
display(robust_grid_candidates_df["matrix_family"].value_counts(dropna=False))
# Out:
# Database loaded
# n objects: 1262
# n images: 48
#   wavelength_mode  use_wavelength_window    results_tag  window_min_nm  \
# 0   non_noisy_all                  False  non_noisy_all            NaN
#
#    window_max_nm  n_bands  min_wavelength_nm  max_wavelength_nm
# 0            NaN       63         960.735294             1702.0
# PCA selected preprocessings: (17, 11)
# 04A grid candidates: (22, 69)
# 04B final candidate panel: (18, 57)
# matrix_family
# object_matrix    12
# pixel_matrix      6
# Name: count, dtype: int64

# %%
required_04b_cols = [
    "selected_config_id",
    "matrix_family",
    "object_threshold",
    "three_way_lower_threshold",
    "three_way_upper_threshold",
]

missing_04b_cols = [
    col for col in required_04b_cols
    if col not in robust_grid_candidates_df.columns
]

if missing_04b_cols:
    raise KeyError(
        "04B final candidate panel is missing required columns: "
        f"{missing_04b_cols}. Re-run 04B after the 3-way/Pareto refactor."
    )

# %%
DEFAULT_OPTUNA_PREPROCESSING_CONFIGS = {
    "snv": ("snv",),
    "absorbance": ("absorbance",),
    "absorbance_snv": ("absorbance", "snv"),
    "absorbance_sg_smooth": ("absorbance", "sg_smooth"),
    "absorbance_sg_d1": ("absorbance", "sg_d1"),
    "absorbance_snv_sg_smooth": ("absorbance", "snv", "sg_smooth"),
    "absorbance_snv_sg_d1": ("absorbance", "snv", "sg_d1"),
    "snv_sg_d1": ("snv", "sg_d1"),
}

if len(pca_selected_preprocessings_df) > 0:
    PREPROCESSING_CONFIGS = build_pca_preprocessing_configs_by_matrix_family(
        pca_selected_preprocessings_df
    )
    print("Using PCA preprocessing shortlist by matrix family.")
else:
    PREPROCESSING_CONFIGS = {
        family: DEFAULT_OPTUNA_PREPROCESSING_CONFIGS.copy()
        for family in expcfg.SIMCA_MATRIX_FAMILIES
    }
    print("[WARNING] Using default Optuna preprocessing configs by matrix family.")

PREPROCESSING_CONFIG_COUNTS = {
    family: len(configs)
    for family, configs in PREPROCESSING_CONFIGS.items()
}

preprocessing_config_df = pd.DataFrame([
    {
        "matrix_family": family,
        "preprocessing": name,
        "preprocessing_steps": "+".join(steps),
        "uses_sg": any(str(step).startswith("sg_") for step in steps),
    }
    for family, configs in PREPROCESSING_CONFIGS.items()
    for name, steps in configs.items()
])

print("Preprocessing configs used by Optuna:", PREPROCESSING_CONFIG_COUNTS)
display(preprocessing_config_df)
# Out:
# Using preprocessing configs from 04B robust candidate panel.
# Preprocessing configs used by Optuna: 7
#               preprocessing       preprocessing_steps  uses_sg
# 0      absorbance_sg_smooth      absorbance+sg_smooth     True
# 1          absorbance_sg_d2          absorbance+sg_d2     True
# 2                       raw                       raw    False
# 3                 sg_smooth                 sg_smooth     True
# 4             snv_sg_smooth             snv+sg_smooth     True
# 5      absorbance_snv_sg_d1      absorbance+snv+sg_d1     True
# 6  absorbance_snv_sg_smooth  absorbance+snv+sg_smooth     True

# %%
# ---------------------------------------------------------------------
# Run Optuna studies separately by matrix family
# ---------------------------------------------------------------------

optuna_trials_parts = []
optuna_completed_parts = []
studies = {}

for matrix_family, space in OPTUNA_MATRIX_FAMILY_SPACES.items():
    print("=" * 80)
    print(f"Optuna study for matrix_family={matrix_family}")
    print("=" * 80)

    storage_path = Path(space["storage_path"])
    storage_path.parent.mkdir(parents=True, exist_ok=True)

    objective = make_optuna_binary_pareto_objective(
        object_db=object_db,
        image_db=image_db,
        train_filters=TRAIN_FILTERS,
        projection_filters=VALIDATION_FILTERS,
        preprocessing_configs=PREPROCESSING_CONFIGS,
        matrix_methods=space["matrix_methods"],
        rule_variants=OPTUNA_RULE_VARIANTS,
        object_thresholds=OPTUNA_OBJECT_THRESHOLDS,
        seeds=OPTUNA_OBJECTIVE_SEEDS,
        n_components_choices=OPTUNA_N_COMPONENTS_CHOICES,
        alpha_choices=OPTUNA_ALPHA_CHOICES,
        m_choices=OPTUNA_M_CHOICES,
        balanced_pixel_strategy_choices=OPTUNA_BALANCED_PIXEL_STRATEGY_CHOICES,
        sg_window_choices=OPTUNA_SG_WINDOW_CHOICES,
        sg_polyorder_choices=OPTUNA_SG_POLYORDER_CHOICES,
        position_dilation_radius_choices=OPTUNA_POSITION_DILATION_RADIUS_CHOICES,
    )

    sampler = optuna.samplers.TPESampler(
        seed=RANDOM_STATE,
        multivariate=True,
        group=True,
        n_startup_trials=30,
    )

    storage = optuna.storages.RDBStorage(
        url=f"sqlite:///{storage_path.as_posix()}",
        engine_kwargs={"connect_args": {"timeout": 30.0}},
    )

    if RUN_OPTUNA:
        study = optuna.create_study(
            study_name=space["study_name"],
            directions=["minimize", "minimize", "maximize"],
            sampler=sampler,
            storage=storage,
            load_if_exists=LOAD_EXISTING_STUDY,
        )

        study.optimize(
            objective,
            n_trials=int(OPTUNA_N_TRIALS_PER_FAMILY[matrix_family]),
            timeout=OPTUNA_TIMEOUT,
            n_jobs=OPTUNA_N_JOBS,
            show_progress_bar=True,
        )

        close_optuna_study(study)

        trials_df = optuna_trials_dataframe(study)

    else:
        if not Path(space["trials_path"]).exists():
            raise FileNotFoundError(
                f"RUN_OPTUNA=False but missing trials file: {space['trials_path']}"
            )
        trials_df = load_parquet(space["trials_path"])

    trials_df = trials_df.copy()
    trials_df["matrix_family_study"] = matrix_family

    save_parquet(trials_df, space["trials_path"])

    completed_df = trials_df[
        trials_df["state"].astype(str).eq("COMPLETE")
    ].copy()

    save_parquet(completed_df, space["completed_trials_path"])

    optuna_trials_parts.append(trials_df)
    optuna_completed_parts.append(completed_df)

    print("Trials:", trials_df.shape)
    print("Completed:", completed_df.shape)
    print("Saved:", space["trials_path"])

optuna_trials_df = (
    pd.concat(optuna_trials_parts, ignore_index=True, sort=False)
    if optuna_trials_parts
    else pd.DataFrame()
)

optuna_completed_trials_df = (
    pd.concat(optuna_completed_parts, ignore_index=True, sort=False)
    if optuna_completed_parts
    else pd.DataFrame()
)

save_parquet(optuna_trials_df, OPTUNA_ALL_TRIALS_PATH)

print("All Optuna trials:", optuna_trials_df.shape)
print("All completed trials:", optuna_completed_trials_df.shape)

display(optuna_completed_trials_df.head(20))
# Out:
# ================================================================================
# Optuna study for matrix_family=object_matrix
# ================================================================================
# c:\Users\alixg\anaconda3\envs\hsi-nuts\Lib\site-packages\optuna\_experimental.py:33: ExperimentalWarning: Argument ``multivariate`` is an experimental feature. The interface can change in the future.
#   optuna_warn(
# c:\Users\alixg\anaconda3\envs\hsi-nuts\Lib\site-packages\optuna\_experimental.py:33: ExperimentalWarning: Argument ``group`` is an experimental feature. The interface can change in the future.
#   optuna_warn(
# [I 2026-07-16 10:26:31,500] A new study created in RDB with name: simca_optuna_object_matrix_non_noisy_all
#   0%|          | 0/200 [00:00<?, ?it/s]
# [I 2026-07-16 10:26:36,095] Trial 0 finished with values: [0.8113207547169812, 0.05454545454545454, 0.5670668953687822] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'absorbance_snv_sg_d1', 'rule_variant': 'alternative_chi2_fixed2', 'n_components': 11, 'alpha': 0.01, 'sg_window_length': 15, 'sg_polyorder': 2, 'position_dilation_radius': 2}.
# [I 2026-07-16 10:26:39,460] Trial 1 finished with values: [1.0, 0.0, 0.5] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'sg_smooth', 'rule_variant': 'alternative_chi2_emp_cv', 'n_components': 10, 'alpha': 0.05, 'sg_window_length': 11, 'sg_polyorder': 2, 'position_dilation_radius': 3}.
# [I 2026-07-16 10:26:42,441] Trial 2 finished with values: [1.0, 0.0, 0.5] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'raw', 'rule_variant': 'alternative_chi2_emp_cv', 'n_components': 3, 'alpha': 0.01, 'position_dilation_radius': 4}.
# [I 2026-07-16 10:26:47,228] Trial 3 finished with values: [0.4528301886792453, 0.2727272727272727, 0.6372212692967409] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'absorbance_sg_d2', 'rule_variant': 'alternative_chi2_emp_cv', 'n_components': 11, 'alpha': 0.01, 'sg_window_length': 9, 'sg_polyorder': 2, 'position_dilation_radius': 5}.
# [I 2026-07-16 10:26:50,486] Trial 4 finished with values: [1.0, 0.0, 0.5] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'absorbance_snv_sg_d1', 'rule_variant': 'simple_emp_cv', 'n_components': 3, 'alpha': 0.05, 'sg_window_length': 11, 'sg_polyorder': 2, 'position_dilation_radius': 3}.
# [I 2026-07-16 10:26:53,810] Trial 5 finished with values: [0.16981132075471697, 0.6545454545454545, 0.5878216123499143] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'absorbance_snv_sg_d1', 'rule_variant': 'alternative_chi2_emp_cv', 'n_components': 3, 'alpha': 0.05, 'sg_window_length': 13, 'sg_polyorder': 2, 'position_dilation_radius': 2}.
# [I 2026-07-16 10:26:57,167] Trial 6 finished with values: [1.0, 0.0, 0.5] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'absorbance_sg_d2', 'rule_variant': 'combined_index_chi2', 'n_components': 10, 'alpha': 0.01, 'sg_window_length': 15, 'sg_polyorder': 2, 'position_dilation_radius': 2}.
# [I 2026-07-16 10:27:00,494] Trial 7 finished with values: [1.0, 0.0, 0.5] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'absorbance_sg_d2', 'rule_variant': 'alternative_chi2_emp_cv', 'n_components': 4, 'alpha': 0.01, 'sg_window_length': 11, 'sg_polyorder': 2, 'position_dilation_radius': 3}.
# [I 2026-07-16 10:27:03,769] Trial 8 finished with values: [0.5660377358490566, 0.07272727272727272, 0.6806174957118354] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'snv_sg_smooth', 'rule_variant': 'alternative_empHQ_emp_cv', 'n_components': 11, 'alpha': 0.01, 'sg_window_length': 13, 'sg_polyorder': 2, 'position_dilation_radius': 5}.
# [I 2026-07-16 10:27:07,077] Trial 9 finished with values: [1.0, 0.0, 0.5] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'absorbance_snv_sg_smooth', 'rule_variant': 'alternative_empHQ_emp_cv', 'n_components': 6, 'alpha': 0.05, 'sg_window_length': 7, 'sg_polyorder': 2, 'position_dilation_radius': 4}.
# [I 2026-07-16 10:27:10,323] Trial 10 finished with values: [0.39622641509433965, 0.01818181818181818, 0.792795883361921] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'absorbance_snv_sg_smooth', 'rule_variant': 'data_driven_chi2', 'n_components': 5, 'alpha': 0.01, 'sg_window_length': 15, 'sg_polyorder': 2, 'position_dilation_radius': 5}.
# [I 2026-07-16 10:27:13,671] Trial 11 finished with values: [0.018867924528301886, 0.9818181818181818, 0.49965694682675815] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'absorbance_snv_sg_d1', 'rule_variant': 'alternative_empHQ_emp_cv', 'n_components': 10, 'alpha': 0.01, 'sg_window_length': 15, 'sg_polyorder': 2, 'position_dilation_radius': 5}.
# [I 2026-07-16 10:27:16,987] Trial 12 finished with values: [1.0, 0.0, 0.5] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'absorbance_sg_smooth', 'rule_variant': 'alternative_empHQ_fixed2', 'n_components': 10, 'alpha': 0.05, 'sg_window_length': 9, 'sg_polyorder': 2, 'position_dilation_radius': 5}.
# [I 2026-07-16 10:27:20,562] Trial 13 finished with values: [0.8301886792452831, 0.0, 0.5849056603773585] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'absorbance_sg_smooth', 'rule_variant': 'simple_emp_cv', 'n_components': 4, 'alpha': 0.01, 'sg_window_length': 7, 'sg_polyorder': 2, 'position_dilation_radius': 2}.
# [I 2026-07-16 10:27:23,611] Trial 14 finished with values: [1.0, 0.0, 0.5] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'raw', 'rule_variant': 'alternative_empHQ_fixed2', 'n_components': 10, 'alpha': 0.05, 'position_dilation_radius': 4}.
# [I 2026-07-16 10:27:26,971] Trial 15 finished with values: [1.0, 0.0, 0.5] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'absorbance_snv_sg_smooth', 'rule_variant': 'data_driven_chi2', 'n_components': 6, 'alpha': 0.05, 'sg_window_length': 11, 'sg_polyorder': 2, 'position_dilation_radius': 2}.
# [I 2026-07-16 10:27:30,272] Trial 16 finished with values: [1.0, 0.0, 0.5] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'absorbance_snv_sg_d1', 'rule_variant': 'combined_index_chi2', 'n_components': 5, 'alpha': 0.01, 'sg_window_length': 15, 'sg_polyorder': 2, 'position_dilation_radius': 3}.
# [I 2026-07-16 10:27:33,687] Trial 17 finished with values: [1.0, 0.0, 0.5] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'absorbance_sg_d2', 'rule_variant': 'simple_chi2', 'n_components': 11, 'alpha': 0.05, 'sg_window_length': 15, 'sg_polyorder': 2, 'position_dilation_radius': 3}.
# [I 2026-07-16 10:27:36,635] Trial 18 finished with values: [0.018867924528301886, 0.9272727272727272, 0.5269296740994854] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'raw', 'rule_variant': 'simple_emp_cv', 'n_components': 6, 'alpha': 0.01, 'position_dilation_radius': 4}.
# [I 2026-07-16 10:27:39,883] Trial 19 finished with values: [0.6226415094339622, 0.0, 0.6886792452830188] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'absorbance_snv_sg_smooth', 'rule_variant': 'simple_emp_cv', 'n_components': 3, 'alpha': 0.01, 'sg_window_length': 9, 'sg_polyorder': 2, 'position_dilation_radius': 3}.
# [I 2026-07-16 10:27:43,389] Trial 20 finished with values: [0.49056603773584906, 0.0, 0.7547169811320756] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'snv_sg_smooth', 'rule_variant': 'alternative_empHQ_fixed2', 'n_components': 7, 'alpha': 0.01, 'sg_window_length': 7, 'sg_polyorder': 2, 'position_dilation_radius': 3}.
# [I 2026-07-16 10:27:46,798] Trial 21 finished with values: [1.0, 0.0, 0.5] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'snv_sg_smooth', 'rule_variant': 'alternative_empHQ_fixed2', 'n_components': 8, 'alpha': 0.05, 'sg_window_length': 9, 'sg_polyorder': 2, 'position_dilation_radius': 5}.
# [I 2026-07-16 10:27:50,031] Trial 22 finished with values: [1.0, 0.0, 0.5] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'raw', 'rule_variant': 'data_driven_chi2', 'n_components': 12, 'alpha': 0.01, 'position_dilation_radius': 5}.
# [I 2026-07-16 10:27:53,419] Trial 23 finished with values: [1.0, 0.0, 0.5] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'snv_sg_smooth', 'rule_variant': 'data_driven_chi2', 'n_components': 7, 'alpha': 0.05, 'sg_window_length': 9, 'sg_polyorder': 2, 'position_dilation_radius': 5}.
# [I 2026-07-16 10:27:56,708] Trial 24 finished with values: [0.6981132075471698, 0.01818181818181818, 0.641852487135506] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'sg_smooth', 'rule_variant': 'alternative_empHQ_fixed2', 'n_components': 11, 'alpha': 0.01, 'sg_window_length': 9, 'sg_polyorder': 2, 'position_dilation_radius': 4}.
# [I 2026-07-16 10:27:59,971] Trial 25 finished with values: [0.8679245283018868, 0.03636363636363636, 0.5478559176672384] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'absorbance_sg_smooth', 'rule_variant': 'combined_index_chi2', 'n_components': 8, 'alpha': 0.01, 'sg_window_length': 7, 'sg_polyorder': 2, 'position_dilation_radius': 4}.
# [I 2026-07-16 10:28:03,420] Trial 26 finished with values: [1.0, 0.0, 0.5] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'absorbance_sg_d2', 'rule_variant': 'alternative_empHQ_fixed2', 'n_components': 6, 'alpha': 0.01, 'sg_window_length': 9, 'sg_polyorder': 2, 'position_dilation_radius': 2}.
# [I 2026-07-16 10:28:06,565] Trial 27 finished with values: [0.5471698113207547, 0.14545454545454545, 0.6536878216123498] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'sg_smooth', 'rule_variant': 'combined_index_chi2', 'n_components': 3, 'alpha': 0.05, 'sg_window_length': 11, 'sg_polyorder': 2, 'position_dilation_radius': 3}.
# [I 2026-07-16 10:28:09,862] Trial 28 finished with values: [0.9245283018867925, 0.0, 0.5377358490566038] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'absorbance_snv_sg_smooth', 'rule_variant': 'simple_emp_cv', 'n_components': 3, 'alpha': 0.05, 'sg_window_length': 9, 'sg_polyorder': 2, 'position_dilation_radius': 3}.
# [I 2026-07-16 10:28:13,058] Trial 29 finished with values: [0.018867924528301886, 0.9818181818181818, 0.49965694682675815] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'snv_sg_smooth', 'rule_variant': 'data_driven_emp_cv', 'n_components': 7, 'alpha': 0.01, 'sg_window_length': 13, 'sg_polyorder': 2, 'position_dilation_radius': 3}.
# [I 2026-07-16 10:28:16,336] Trial 30 finished with values: [0.4528301886792453, 0.03636363636363636, 0.7554030874785592] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'absorbance_snv_sg_smooth', 'rule_variant': 'data_driven_chi2', 'n_components': 5, 'alpha': 0.01, 'sg_window_length': 13, 'sg_polyorder': 2, 'position_dilation_radius': 5}.
# [I 2026-07-16 10:28:19,836] Trial 31 finished with values: [0.018867924528301886, 0.9272727272727272, 0.5269296740994854] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'absorbance_snv_sg_smooth', 'rule_variant': 'alternative_empHQ_emp_cv', 'n_components': 5, 'alpha': 0.01, 'sg_window_length': 15, 'sg_polyorder': 2, 'position_dilation_radius': 2}.
# [I 2026-07-16 10:28:23,085] Trial 32 finished with values: [0.16981132075471697, 0.6545454545454545, 0.5878216123499143] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'absorbance_snv_sg_d1', 'rule_variant': 'alternative_chi2_emp_cv', 'n_components': 3, 'alpha': 0.05, 'sg_window_length': 13, 'sg_polyorder': 2, 'position_dilation_radius': 5}.
# [I 2026-07-16 10:28:26,150] Trial 33 finished with values: [0.49056603773584906, 0.16363636363636364, 0.6728987993138936] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'raw', 'rule_variant': 'alternative_chi2_emp_cv', 'n_components': 3, 'alpha': 0.05, 'position_dilation_radius': 2}.
# [I 2026-07-16 10:28:29,434] Trial 34 finished with values: [0.4528301886792453, 0.01818181818181818, 0.7644939965694683] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'absorbance_snv_sg_d1', 'rule_variant': 'data_driven_chi2', 'n_components': 3, 'alpha': 0.05, 'sg_window_length': 15, 'sg_polyorder': 2, 'position_dilation_radius': 2}.
# [I 2026-07-16 10:28:32,751] Trial 35 finished with values: [0.3018867924528302, 0.10909090909090909, 0.7945111492281303] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'absorbance_snv_sg_smooth', 'rule_variant': 'simple_chi2', 'n_components': 4, 'alpha': 0.01, 'sg_window_length': 15, 'sg_polyorder': 2, 'position_dilation_radius': 5}.
# [I 2026-07-16 10:28:36,032] Trial 36 finished with values: [0.0, 0.9636363636363635, 0.5181818181818182] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'absorbance_snv_sg_smooth', 'rule_variant': 'data_driven_emp_cv', 'n_components': 4, 'alpha': 0.01, 'sg_window_length': 15, 'sg_polyorder': 2, 'position_dilation_radius': 5}.
# [I 2026-07-16 10:28:39,248] Trial 37 finished with values: [0.9056603773584906, 0.01818181818181818, 0.5380789022298457] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'absorbance_sg_d2', 'rule_variant': 'simple_chi2', 'n_components': 4, 'alpha': 0.01, 'sg_window_length': 15, 'sg_polyorder': 2, 'position_dilation_radius': 5}.
# [I 2026-07-16 10:28:42,671] Trial 38 finished with values: [0.9622641509433962, 0.0, 0.5188679245283019] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'absorbance_snv_sg_smooth', 'rule_variant': 'simple_chi2', 'n_components': 7, 'alpha': 0.05, 'sg_window_length': 15, 'sg_polyorder': 2, 'position_dilation_radius': 5}.
# [I 2026-07-16 10:28:46,137] Trial 39 finished with values: [1.0, 0.0, 0.5] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'absorbance_snv_sg_d1', 'rule_variant': 'alternative_chi2_emp_cv', 'n_components': 12, 'alpha': 0.05, 'sg_window_length': 13, 'sg_polyorder': 2, 'position_dilation_radius': 2}.
# [I 2026-07-16 10:28:49,191] Trial 40 finished with values: [1.0, 0.0, 0.5] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'raw', 'rule_variant': 'simple_chi2', 'n_components': 10, 'alpha': 0.01, 'position_dilation_radius': 4}.
# [I 2026-07-16 10:28:52,523] Trial 41 finished with values: [1.0, 0.0, 0.5] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'absorbance_snv_sg_smooth', 'rule_variant': 'simple_chi2', 'n_components': 4, 'alpha': 0.01, 'sg_window_length': 15, 'sg_polyorder': 2, 'position_dilation_radius': 5}.
# [I 2026-07-16 10:28:55,880] Trial 42 finished with values: [0.5849056603773585, 0.03636363636363636, 0.6893653516295025] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'absorbance_snv_sg_smooth', 'rule_variant': 'simple_chi2', 'n_components': 6, 'alpha': 0.01, 'sg_window_length': 15, 'sg_polyorder': 2, 'position_dilation_radius': 5}.
# [I 2026-07-16 10:28:59,144] Trial 43 finished with values: [0.37735849056603776, 0.07272727272727272, 0.7749571183533449] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'absorbance_snv_sg_smooth', 'rule_variant': 'simple_chi2', 'n_components': 4, 'alpha': 0.01, 'sg_window_length': 7, 'sg_polyorder': 2, 'position_dilation_radius': 4}.
# [I 2026-07-16 10:29:02,351] Trial 44 finished with values: [0.3584905660377358, 0.12727272727272726, 0.7571183533447684] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'sg_smooth', 'rule_variant': 'simple_chi2', 'n_components': 4, 'alpha': 0.01, 'sg_window_length': 11, 'sg_polyorder': 2, 'position_dilation_radius': 2}.
# [I 2026-07-16 10:29:05,678] Trial 45 finished with values: [0.018867924528301886, 0.9818181818181818, 0.49965694682675815] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'absorbance_snv_sg_smooth', 'rule_variant': 'alternative_empHQ_fixed2', 'n_components': 3, 'alpha': 0.01, 'sg_window_length': 15, 'sg_polyorder': 2, 'position_dilation_radius': 5}.
# [I 2026-07-16 10:29:09,041] Trial 46 finished with values: [0.6037735849056604, 0.10909090909090909, 0.6435677530017152] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'snv_sg_smooth', 'rule_variant': 'simple_chi2', 'n_components': 10, 'alpha': 0.01, 'sg_window_length': 13, 'sg_polyorder': 2, 'position_dilation_radius': 5}.
# [I 2026-07-16 10:29:12,672] Trial 47 finished with values: [0.9811320754716981, 0.01818181818181818, 0.5003430531732419] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'absorbance_sg_d2', 'rule_variant': 'combined_index_chi2', 'n_components': 7, 'alpha': 0.05, 'sg_window_length': 7, 'sg_polyorder': 2, 'position_dilation_radius': 2}.
# [I 2026-07-16 10:29:15,991] Trial 48 finished with values: [0.6981132075471698, 0.0909090909090909, 0.6054888507718696] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'absorbance_snv_sg_smooth', 'rule_variant': 'alternative_chi2_fixed2', 'n_components': 11, 'alpha': 0.01, 'sg_window_length': 15, 'sg_polyorder': 2, 'position_dilation_radius': 3}.
# [I 2026-07-16 10:29:19,183] Trial 49 finished with values: [0.20754716981132076, 0.4909090909090909, 0.6507718696397942] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'absorbance_snv_sg_smooth', 'rule_variant': 'alternative_chi2_emp_cv', 'n_components': 4, 'alpha': 0.05, 'sg_window_length': 11, 'sg_polyorder': 2, 'position_dilation_radius': 5}.
# [I 2026-07-16 10:29:22,524] Trial 50 finished with values: [0.018867924528301886, 0.9272727272727272, 0.5269296740994854] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'absorbance_snv_sg_smooth', 'rule_variant': 'simple_emp_cv', 'n_components': 4, 'alpha': 0.01, 'sg_window_length': 11, 'sg_polyorder': 2, 'position_dilation_radius': 2}.
# [I 2026-07-16 10:29:25,814] Trial 51 finished with values: [0.3584905660377358, 0.14545454545454545, 0.7480274442538594] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'absorbance_snv_sg_smooth', 'rule_variant': 'combined_index_chi2', 'n_components': 4, 'alpha': 0.05, 'sg_window_length': 11, 'sg_polyorder': 2, 'position_dilation_radius': 5}.
# [I 2026-07-16 10:29:28,906] Trial 52 finished with values: [0.018867924528301886, 0.9272727272727272, 0.5269296740994854] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'raw', 'rule_variant': 'simple_emp_cv', 'n_components': 6, 'alpha': 0.01, 'position_dilation_radius': 4}.
# [I 2026-07-16 10:29:32,209] Trial 53 finished with values: [0.22641509433962265, 0.4727272727272727, 0.6504288164665524] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'absorbance_snv_sg_smooth', 'rule_variant': 'alternative_chi2_emp_cv', 'n_components': 4, 'alpha': 0.05, 'sg_window_length': 15, 'sg_polyorder': 2, 'position_dilation_radius': 2}.
# [I 2026-07-16 10:29:35,468] Trial 54 finished with values: [0.6981132075471698, 0.0, 0.6509433962264151] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'absorbance_snv_sg_smooth', 'rule_variant': 'simple_chi2', 'n_components': 4, 'alpha': 0.05, 'sg_window_length': 11, 'sg_polyorder': 2, 'position_dilation_radius': 3}.
# [I 2026-07-16 10:29:38,736] Trial 55 finished with values: [0.4528301886792453, 0.16363636363636364, 0.6917667238421955] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'absorbance_sg_d2', 'rule_variant': 'data_driven_emp_cv', 'n_components': 5, 'alpha': 0.05, 'sg_window_length': 15, 'sg_polyorder': 2, 'position_dilation_radius': 5}.
# [I 2026-07-16 10:29:42,077] Trial 56 finished with values: [0.2830188679245283, 0.2909090909090909, 0.7130360205831904] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'absorbance_snv_sg_smooth', 'rule_variant': 'alternative_chi2_emp_cv', 'n_components': 6, 'alpha': 0.05, 'sg_window_length': 7, 'sg_polyorder': 2, 'position_dilation_radius': 5}.
# [I 2026-07-16 10:29:45,410] Trial 57 finished with values: [0.39622641509433965, 0.34545454545454546, 0.6291595197255575] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'absorbance_snv_sg_smooth', 'rule_variant': 'alternative_chi2_emp_cv', 'n_components': 8, 'alpha': 0.05, 'sg_window_length': 11, 'sg_polyorder': 2, 'position_dilation_radius': 5}.
# [I 2026-07-16 10:29:48,667] Trial 58 finished with values: [0.2830188679245283, 0.2909090909090909, 0.7130360205831904] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'absorbance_snv_sg_smooth', 'rule_variant': 'alternative_chi2_emp_cv', 'n_components': 6, 'alpha': 0.05, 'sg_window_length': 7, 'sg_polyorder': 2, 'position_dilation_radius': 4}.
# [I 2026-07-16 10:29:52,011] Trial 59 finished with values: [1.0, 0.0, 0.5] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'absorbance_snv_sg_smooth', 'rule_variant': 'alternative_chi2_fixed2', 'n_components': 5, 'alpha': 0.05, 'sg_window_length': 15, 'sg_polyorder': 2, 'position_dilation_radius': 5}.
# [I 2026-07-16 10:29:55,530] Trial 60 finished with values: [0.5471698113207547, 0.1818181818181818, 0.6355060034305318] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'absorbance_sg_smooth', 'rule_variant': 'alternative_chi2_fixed2', 'n_components': 4, 'alpha': 0.01, 'sg_window_length': 11, 'sg_polyorder': 2, 'position_dilation_radius': 5}.
# [I 2026-07-16 10:29:59,766] Trial 61 finished with values: [1.0, 0.0, 0.5] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'absorbance_snv_sg_d1', 'rule_variant': 'simple_chi2', 'n_components': 7, 'alpha': 0.01, 'sg_window_length': 7, 'sg_polyorder': 2, 'position_dilation_radius': 2}.
# [I 2026-07-16 10:30:03,838] Trial 62 finished with values: [0.4339622641509434, 0.10909090909090909, 0.7284734133790738] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'raw', 'rule_variant': 'alternative_chi2_emp_cv', 'n_components': 4, 'alpha': 0.05, 'position_dilation_radius': 5}.
# [I 2026-07-16 10:30:07,933] Trial 63 finished with values: [0.3018867924528302, 0.10909090909090909, 0.7945111492281303] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'absorbance_snv_sg_smooth', 'rule_variant': 'simple_chi2', 'n_components': 4, 'alpha': 0.01, 'sg_window_length': 15, 'sg_polyorder': 2, 'position_dilation_radius': 5}.
# [I 2026-07-16 10:30:12,330] Trial 64 finished with values: [0.0, 0.9636363636363635, 0.5181818181818182] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'sg_smooth', 'rule_variant': 'simple_emp_cv', 'n_components': 7, 'alpha': 0.01, 'sg_window_length': 13, 'sg_polyorder': 2, 'position_dilation_radius': 5}.
# [I 2026-07-16 10:30:16,037] Trial 65 finished with values: [1.0, 0.0, 0.5] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'raw', 'rule_variant': 'alternative_chi2_fixed2', 'n_components': 7, 'alpha': 0.01, 'position_dilation_radius': 3}.
# [I 2026-07-16 10:30:20,112] Trial 66 finished with values: [0.1320754716981132, 0.6727272727272727, 0.5975986277873071] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'snv_sg_smooth', 'rule_variant': 'alternative_chi2_emp_cv', 'n_components': 6, 'alpha': 0.05, 'sg_window_length': 15, 'sg_polyorder': 2, 'position_dilation_radius': 5}.
# [I 2026-07-16 10:30:23,865] Trial 67 finished with values: [0.1320754716981132, 0.6727272727272727, 0.5975986277873071] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'snv_sg_smooth', 'rule_variant': 'alternative_chi2_emp_cv', 'n_components': 6, 'alpha': 0.05, 'sg_window_length': 15, 'sg_polyorder': 2, 'position_dilation_radius': 5}.
# [I 2026-07-16 10:30:27,482] Trial 68 finished with values: [0.33962264150943394, 0.32727272727272727, 0.6665523156089194] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'absorbance_snv_sg_smooth', 'rule_variant': 'simple_emp_cv', 'n_components': 6, 'alpha': 0.05, 'sg_window_length': 15, 'sg_polyorder': 2, 'position_dilation_radius': 5}.
# [I 2026-07-16 10:30:31,015] Trial 69 finished with values: [0.9811320754716981, 0.0, 0.5094339622641509] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'absorbance_snv_sg_d1', 'rule_variant': 'simple_chi2', 'n_components': 12, 'alpha': 0.01, 'sg_window_length': 7, 'sg_polyorder': 2, 'position_dilation_radius': 5}.
# [I 2026-07-16 10:30:34,380] Trial 70 finished with values: [1.0, 0.0, 0.5] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'absorbance_snv_sg_smooth', 'rule_variant': 'alternative_chi2_emp_cv', 'n_components': 6, 'alpha': 0.05, 'sg_window_length': 15, 'sg_polyorder': 2, 'position_dilation_radius': 5}.
# [I 2026-07-16 10:30:37,717] Trial 71 finished with values: [0.41509433962264153, 0.0909090909090909, 0.7469982847341338] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'absorbance_snv_sg_smooth', 'rule_variant': 'data_driven_chi2', 'n_components': 4, 'alpha': 0.01, 'sg_window_length': 7, 'sg_polyorder': 2, 'position_dilation_radius': 3}.
# [I 2026-07-16 10:30:41,306] Trial 72 finished with values: [1.0, 0.0, 0.5] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'snv_sg_smooth', 'rule_variant': 'alternative_empHQ_fixed2', 'n_components': 7, 'alpha': 0.05, 'sg_window_length': 11, 'sg_polyorder': 2, 'position_dilation_radius': 3}.
# [I 2026-07-16 10:30:44,727] Trial 73 finished with values: [0.41509433962264153, 0.01818181818181818, 0.7833619210977701] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'absorbance_snv_sg_smooth', 'rule_variant': 'simple_chi2', 'n_components': 3, 'alpha': 0.01, 'sg_window_length': 9, 'sg_polyorder': 2, 'position_dilation_radius': 4}.
# [I 2026-07-16 10:30:48,856] Trial 74 finished with values: [0.07547169811320754, 0.8181818181818182, 0.5531732418524872] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'sg_smooth', 'rule_variant': 'alternative_empHQ_emp_cv', 'n_components': 4, 'alpha': 0.01, 'sg_window_length': 15, 'sg_polyorder': 2, 'position_dilation_radius': 5}.
# [I 2026-07-16 10:31:00,395] Trial 75 finished with values: [1.0, 0.0, 0.5] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'absorbance_snv_sg_smooth', 'rule_variant': 'data_driven_chi2', 'n_components': 7, 'alpha': 0.01, 'sg_window_length': 15, 'sg_polyorder': 2, 'position_dilation_radius': 5}.
# [I 2026-07-16 10:31:07,436] Trial 76 finished with values: [0.0, 0.9636363636363635, 0.5181818181818182] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'snv_sg_smooth', 'rule_variant': 'alternative_chi2_emp_cv', 'n_components': 4, 'alpha': 0.01, 'sg_window_length': 15, 'sg_polyorder': 2, 'position_dilation_radius': 5}.
# [I 2026-07-16 10:31:14,424] Trial 77 finished with values: [0.4339622641509434, 0.2545454545454545, 0.655746140651801] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'absorbance_snv_sg_smooth', 'rule_variant': 'combined_index_chi2', 'n_components': 8, 'alpha': 0.01, 'sg_window_length': 15, 'sg_polyorder': 2, 'position_dilation_radius': 5}.
# [I 2026-07-16 10:31:21,195] Trial 78 finished with values: [0.8113207547169812, 0.0, 0.5943396226415094] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'sg_smooth', 'rule_variant': 'alternative_chi2_fixed2', 'n_components': 10, 'alpha': 0.05, 'sg_window_length': 9, 'sg_polyorder': 2, 'position_dilation_radius': 5}.
# [I 2026-07-16 10:31:27,184] Trial 79 finished with values: [0.018867924528301886, 0.8545454545454545, 0.5632933104631218] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'sg_smooth', 'rule_variant': 'alternative_empHQ_emp_cv', 'n_components': 5, 'alpha': 0.01, 'sg_window_length': 15, 'sg_polyorder': 2, 'position_dilation_radius': 5}.
# [I 2026-07-16 10:31:34,039] Trial 80 finished with values: [0.1320754716981132, 0.7090909090909091, 0.5794168096054888] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'snv_sg_smooth', 'rule_variant': 'simple_emp_cv', 'n_components': 4, 'alpha': 0.05, 'sg_window_length': 7, 'sg_polyorder': 2, 'position_dilation_radius': 5}.
# [I 2026-07-16 10:31:41,595] Trial 81 finished with values: [0.0, 0.9272727272727272, 0.5363636363636364] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'sg_smooth', 'rule_variant': 'data_driven_emp_cv', 'n_components': 5, 'alpha': 0.01, 'sg_window_length': 15, 'sg_polyorder': 2, 'position_dilation_radius': 5}.
# [I 2026-07-16 10:31:49,083] Trial 82 finished with values: [0.03773584905660377, 0.9090909090909091, 0.5265866209262435] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'absorbance_snv_sg_smooth', 'rule_variant': 'alternative_empHQ_emp_cv', 'n_components': 7, 'alpha': 0.01, 'sg_window_length': 15, 'sg_polyorder': 2, 'position_dilation_radius': 5}.
# [I 2026-07-16 10:31:57,163] Trial 83 finished with values: [0.3018867924528302, 0.03636363636363636, 0.8308747855917668] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'snv_sg_smooth', 'rule_variant': 'alternative_empHQ_fixed2', 'n_components': 5, 'alpha': 0.01, 'sg_window_length': 15, 'sg_polyorder': 2, 'position_dilation_radius': 3}.
# [I 2026-07-16 10:32:05,933] Trial 84 finished with values: [0.3018867924528302, 0.03636363636363636, 0.8308747855917668] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'snv_sg_smooth', 'rule_variant': 'alternative_empHQ_fixed2', 'n_components': 5, 'alpha': 0.01, 'sg_window_length': 15, 'sg_polyorder': 2, 'position_dilation_radius': 3}.
# [I 2026-07-16 10:32:13,502] Trial 85 finished with values: [0.8867924528301887, 0.0, 0.5566037735849056] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'absorbance_snv_sg_smooth', 'rule_variant': 'alternative_empHQ_fixed2', 'n_components': 10, 'alpha': 0.01, 'sg_window_length': 13, 'sg_polyorder': 2, 'position_dilation_radius': 3}.
# [I 2026-07-16 10:32:22,016] Trial 86 finished with values: [0.7358490566037735, 0.0, 0.6320754716981132] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'snv_sg_smooth', 'rule_variant': 'alternative_empHQ_emp_cv', 'n_components': 5, 'alpha': 0.01, 'sg_window_length': 9, 'sg_polyorder': 2, 'position_dilation_radius': 4}.
# [I 2026-07-16 10:32:29,718] Trial 87 finished with values: [0.03773584905660377, 0.9818181818181818, 0.4902229845626072] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'snv_sg_smooth', 'rule_variant': 'alternative_chi2_emp_cv', 'n_components': 12, 'alpha': 0.01, 'sg_window_length': 15, 'sg_polyorder': 2, 'position_dilation_radius': 3}.
# [I 2026-07-16 10:32:38,592] Trial 88 finished with values: [0.9811320754716981, 0.0, 0.5094339622641509] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'snv_sg_smooth', 'rule_variant': 'alternative_empHQ_emp_cv', 'n_components': 5, 'alpha': 0.05, 'sg_window_length': 15, 'sg_polyorder': 2, 'position_dilation_radius': 3}.
# [I 2026-07-16 10:32:47,011] Trial 89 finished with values: [1.0, 0.0, 0.5] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'sg_smooth', 'rule_variant': 'data_driven_chi2', 'n_components': 5, 'alpha': 0.01, 'sg_window_length': 15, 'sg_polyorder': 2, 'position_dilation_radius': 3}.
# [I 2026-07-16 10:32:54,967] Trial 90 finished with values: [0.49056603773584906, 0.07272727272727272, 0.7183533447684392] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'sg_smooth', 'rule_variant': 'alternative_empHQ_fixed2', 'n_components': 12, 'alpha': 0.01, 'sg_window_length': 13, 'sg_polyorder': 2, 'position_dilation_radius': 3}.
# [I 2026-07-16 10:33:01,246] Trial 91 finished with values: [0.0, 0.9818181818181818, 0.509090909090909] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'snv_sg_smooth', 'rule_variant': 'alternative_empHQ_fixed2', 'n_components': 6, 'alpha': 0.01, 'sg_window_length': 15, 'sg_polyorder': 2, 'position_dilation_radius': 3}.
# [I 2026-07-16 10:33:07,810] Trial 92 finished with values: [0.9811320754716981, 0.0, 0.5094339622641509] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'snv_sg_smooth', 'rule_variant': 'data_driven_chi2', 'n_components': 4, 'alpha': 0.01, 'sg_window_length': 15, 'sg_polyorder': 2, 'position_dilation_radius': 3}.
# [I 2026-07-16 10:33:14,468] Trial 93 finished with values: [1.0, 0.0, 0.5] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'snv_sg_smooth', 'rule_variant': 'simple_chi2', 'n_components': 8, 'alpha': 0.01, 'sg_window_length': 15, 'sg_polyorder': 2, 'position_dilation_radius': 3}.
# [I 2026-07-16 10:33:21,179] Trial 94 finished with values: [1.0, 0.0, 0.5] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'absorbance_snv_sg_d1', 'rule_variant': 'alternative_empHQ_fixed2', 'n_components': 5, 'alpha': 0.01, 'sg_window_length': 9, 'sg_polyorder': 2, 'position_dilation_radius': 2}.
# [I 2026-07-16 10:33:28,048] Trial 95 finished with values: [0.6415094339622641, 0.0, 0.6792452830188679] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'absorbance_sg_smooth', 'rule_variant': 'simple_emp_cv', 'n_components': 5, 'alpha': 0.01, 'sg_window_length': 15, 'sg_polyorder': 2, 'position_dilation_radius': 3}.
# [I 2026-07-16 10:33:34,680] Trial 96 finished with values: [0.6981132075471698, 0.0, 0.6509433962264151] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'absorbance_sg_smooth', 'rule_variant': 'alternative_empHQ_fixed2', 'n_components': 5, 'alpha': 0.01, 'sg_window_length': 15, 'sg_polyorder': 2, 'position_dilation_radius': 5}.
# [I 2026-07-16 10:33:41,191] Trial 97 finished with values: [1.0, 0.0, 0.5] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'snv_sg_smooth', 'rule_variant': 'alternative_chi2_fixed2', 'n_components': 5, 'alpha': 0.01, 'sg_window_length': 7, 'sg_polyorder': 2, 'position_dilation_radius': 2}.
# [I 2026-07-16 10:33:47,249] Trial 98 finished with values: [0.8679245283018868, 0.0, 0.5660377358490566] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'raw', 'rule_variant': 'alternative_empHQ_fixed2', 'n_components': 3, 'alpha': 0.01, 'position_dilation_radius': 3}.
# [I 2026-07-16 10:33:53,698] Trial 99 finished with values: [0.5849056603773585, 0.12727272727272726, 0.6439108061749571] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'absorbance_sg_smooth', 'rule_variant': 'alternative_chi2_emp_cv', 'n_components': 7, 'alpha': 0.05, 'sg_window_length': 13, 'sg_polyorder': 2, 'position_dilation_radius': 3}.
# [I 2026-07-16 10:34:00,288] Trial 100 finished with values: [0.09433962264150944, 0.7454545454545455, 0.5801029159519726] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'snv_sg_smooth', 'rule_variant': 'data_driven_emp_cv', 'n_components': 11, 'alpha': 0.01, 'sg_window_length': 11, 'sg_polyorder': 2, 'position_dilation_radius': 3}.
# [I 2026-07-16 10:34:06,595] Trial 101 finished with values: [1.0, 0.0, 0.5] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'absorbance_sg_smooth', 'rule_variant': 'alternative_empHQ_fixed2', 'n_components': 5, 'alpha': 0.05, 'sg_window_length': 11, 'sg_polyorder': 2, 'position_dilation_radius': 3}.
# [I 2026-07-16 10:34:13,104] Trial 102 finished with values: [1.0, 0.0, 0.5] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'sg_smooth', 'rule_variant': 'simple_chi2', 'n_components': 5, 'alpha': 0.05, 'sg_window_length': 15, 'sg_polyorder': 2, 'position_dilation_radius': 4}.
# [I 2026-07-16 10:34:19,053] Trial 103 finished with values: [0.09433962264150944, 0.7454545454545455, 0.5801029159519726] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'snv_sg_smooth', 'rule_variant': 'data_driven_emp_cv', 'n_components': 11, 'alpha': 0.01, 'sg_window_length': 11, 'sg_polyorder': 2, 'position_dilation_radius': 3}.
# [I 2026-07-16 10:34:25,591] Trial 104 finished with values: [0.20754716981132076, 0.4909090909090909, 0.6507718696397942] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'absorbance_snv_sg_smooth', 'rule_variant': 'alternative_chi2_emp_cv', 'n_components': 4, 'alpha': 0.05, 'sg_window_length': 9, 'sg_polyorder': 2, 'position_dilation_radius': 2}.
# [I 2026-07-16 10:34:31,890] Trial 105 finished with values: [0.2641509433962264, 0.0, 0.8679245283018867] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'snv_sg_smooth', 'rule_variant': 'alternative_empHQ_fixed2', 'n_components': 3, 'alpha': 0.01, 'sg_window_length': 7, 'sg_polyorder': 2, 'position_dilation_radius': 2}.
# [I 2026-07-16 10:34:39,201] Trial 106 finished with values: [0.2641509433962264, 0.0, 0.8679245283018867] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'snv_sg_smooth', 'rule_variant': 'alternative_empHQ_fixed2', 'n_components': 3, 'alpha': 0.01, 'sg_window_length': 7, 'sg_polyorder': 2, 'position_dilation_radius': 2}.
# [I 2026-07-16 10:34:46,067] Trial 107 finished with values: [0.018867924528301886, 0.8727272727272727, 0.5542024013722127] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'sg_smooth', 'rule_variant': 'alternative_empHQ_emp_cv', 'n_components': 5, 'alpha': 0.01, 'sg_window_length': 7, 'sg_polyorder': 2, 'position_dilation_radius': 5}.
# [I 2026-07-16 10:34:52,568] Trial 108 finished with values: [0.0, 0.9818181818181818, 0.509090909090909] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'snv_sg_smooth', 'rule_variant': 'data_driven_emp_cv', 'n_components': 3, 'alpha': 0.01, 'sg_window_length': 7, 'sg_polyorder': 2, 'position_dilation_radius': 2}.
# [I 2026-07-16 10:34:59,193] Trial 109 finished with values: [1.0, 0.0, 0.5] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'absorbance_sg_d2', 'rule_variant': 'simple_chi2', 'n_components': 3, 'alpha': 0.01, 'sg_window_length': 7, 'sg_polyorder': 2, 'position_dilation_radius': 2}.
# [I 2026-07-16 10:35:05,246] Trial 110 finished with values: [0.9811320754716981, 0.0, 0.5094339622641509] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'snv_sg_smooth', 'rule_variant': 'combined_index_chi2', 'n_components': 3, 'alpha': 0.05, 'sg_window_length': 7, 'sg_polyorder': 2, 'position_dilation_radius': 2}.
# [I 2026-07-16 10:35:11,763] Trial 111 finished with values: [0.8867924528301887, 0.01818181818181818, 0.5475128644939966] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'absorbance_sg_smooth', 'rule_variant': 'combined_index_chi2', 'n_components': 3, 'alpha': 0.01, 'sg_window_length': 7, 'sg_polyorder': 2, 'position_dilation_radius': 2}.
# [I 2026-07-16 10:35:18,462] Trial 112 finished with values: [0.16981132075471697, 0.7090909090909091, 0.5605488850771869] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'snv_sg_smooth', 'rule_variant': 'data_driven_emp_cv', 'n_components': 12, 'alpha': 0.01, 'sg_window_length': 7, 'sg_polyorder': 2, 'position_dilation_radius': 2}.
# [I 2026-07-16 10:35:24,822] Trial 113 finished with values: [0.39622641509433965, 0.0, 0.8018867924528301] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'snv_sg_smooth', 'rule_variant': 'alternative_empHQ_fixed2', 'n_components': 6, 'alpha': 0.01, 'sg_window_length': 7, 'sg_polyorder': 2, 'position_dilation_radius': 2}.
# [I 2026-07-16 10:35:31,521] Trial 114 finished with values: [0.39622641509433965, 0.0, 0.8018867924528301] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'snv_sg_smooth', 'rule_variant': 'simple_emp_cv', 'n_components': 3, 'alpha': 0.01, 'sg_window_length': 7, 'sg_polyorder': 2, 'position_dilation_radius': 2}.
# [I 2026-07-16 10:35:37,985] Trial 115 finished with values: [0.11320754716981132, 0.6909090909090909, 0.5979416809605489] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'snv_sg_smooth', 'rule_variant': 'alternative_empHQ_fixed2', 'n_components': 3, 'alpha': 0.05, 'sg_window_length': 7, 'sg_polyorder': 2, 'position_dilation_radius': 2}.
# [I 2026-07-16 10:35:44,551] Trial 116 finished with values: [0.4339622641509434, 0.0, 0.7830188679245284] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'absorbance_snv_sg_smooth', 'rule_variant': 'alternative_empHQ_fixed2', 'n_components': 3, 'alpha': 0.01, 'sg_window_length': 7, 'sg_polyorder': 2, 'position_dilation_radius': 2}.
# [I 2026-07-16 10:35:50,602] Trial 117 finished with values: [1.0, 0.0, 0.5] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'absorbance_sg_smooth', 'rule_variant': 'alternative_empHQ_fixed2', 'n_components': 11, 'alpha': 0.01, 'sg_window_length': 7, 'sg_polyorder': 2, 'position_dilation_radius': 2}.
# [I 2026-07-16 10:35:57,137] Trial 118 finished with values: [1.0, 0.0, 0.5] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'snv_sg_smooth', 'rule_variant': 'alternative_empHQ_fixed2', 'n_components': 10, 'alpha': 0.05, 'sg_window_length': 7, 'sg_polyorder': 2, 'position_dilation_radius': 2}.
# [I 2026-07-16 10:36:03,542] Trial 119 finished with values: [0.9433962264150944, 0.0, 0.5283018867924528] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'snv_sg_smooth', 'rule_variant': 'simple_chi2', 'n_components': 3, 'alpha': 0.01, 'sg_window_length': 7, 'sg_polyorder': 2, 'position_dilation_radius': 4}.
# [I 2026-07-16 10:36:09,931] Trial 120 finished with values: [0.7735849056603774, 0.0, 0.6132075471698113] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'snv_sg_smooth', 'rule_variant': 'alternative_empHQ_fixed2', 'n_components': 8, 'alpha': 0.01, 'sg_window_length': 7, 'sg_polyorder': 2, 'position_dilation_radius': 4}.
# [I 2026-07-16 10:36:16,681] Trial 121 finished with values: [0.2641509433962264, 0.0, 0.8679245283018867] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'snv_sg_smooth', 'rule_variant': 'alternative_empHQ_fixed2', 'n_components': 3, 'alpha': 0.01, 'sg_window_length': 11, 'sg_polyorder': 2, 'position_dilation_radius': 5}.
# [I 2026-07-16 10:36:23,144] Trial 122 finished with values: [0.0, 0.9818181818181818, 0.509090909090909] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'snv_sg_smooth', 'rule_variant': 'alternative_empHQ_fixed2', 'n_components': 3, 'alpha': 0.01, 'sg_window_length': 7, 'sg_polyorder': 2, 'position_dilation_radius': 2}.
# [I 2026-07-16 10:36:29,507] Trial 123 finished with values: [0.9622641509433962, 0.0, 0.5188679245283019] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'snv_sg_smooth', 'rule_variant': 'data_driven_chi2', 'n_components': 3, 'alpha': 0.01, 'sg_window_length': 11, 'sg_polyorder': 2, 'position_dilation_radius': 2}.
# [I 2026-07-16 10:36:36,099] Trial 124 finished with values: [1.0, 0.0, 0.5] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'absorbance_snv_sg_d1', 'rule_variant': 'alternative_empHQ_fixed2', 'n_components': 3, 'alpha': 0.01, 'sg_window_length': 7, 'sg_polyorder': 2, 'position_dilation_radius': 4}.
# [I 2026-07-16 10:36:42,454] Trial 125 finished with values: [0.5471698113207547, 0.12727272727272726, 0.662778730703259] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'raw', 'rule_variant': 'data_driven_emp_cv', 'n_components': 10, 'alpha': 0.01, 'position_dilation_radius': 5}.
# [I 2026-07-16 10:36:49,077] Trial 126 finished with values: [0.4339622641509434, 0.0, 0.7830188679245284] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'snv_sg_smooth', 'rule_variant': 'simple_chi2', 'n_components': 5, 'alpha': 0.05, 'sg_window_length': 13, 'sg_polyorder': 2, 'position_dilation_radius': 2}.
# [I 2026-07-16 10:36:55,343] Trial 127 finished with values: [1.0, 0.0, 0.5] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'absorbance_sg_smooth', 'rule_variant': 'alternative_empHQ_emp_cv', 'n_components': 8, 'alpha': 0.05, 'sg_window_length': 7, 'sg_polyorder': 2, 'position_dilation_radius': 2}.
# [I 2026-07-16 10:37:01,722] Trial 128 finished with values: [0.20754716981132076, 0.4909090909090909, 0.6507718696397942] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'absorbance_snv_sg_smooth', 'rule_variant': 'alternative_chi2_emp_cv', 'n_components': 4, 'alpha': 0.05, 'sg_window_length': 7, 'sg_polyorder': 2, 'position_dilation_radius': 5}.
# [I 2026-07-16 10:37:08,250] Trial 129 finished with values: [0.11320754716981132, 0.6909090909090909, 0.5979416809605489] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'snv_sg_smooth', 'rule_variant': 'alternative_empHQ_fixed2', 'n_components': 3, 'alpha': 0.05, 'sg_window_length': 11, 'sg_polyorder': 2, 'position_dilation_radius': 4}.
# [I 2026-07-16 10:37:14,829] Trial 130 finished with values: [0.37735849056603776, 0.0, 0.8113207547169812] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'snv_sg_smooth', 'rule_variant': 'data_driven_emp_cv', 'n_components': 3, 'alpha': 0.01, 'sg_window_length': 7, 'sg_polyorder': 2, 'position_dilation_radius': 3}.
# [I 2026-07-16 10:37:21,451] Trial 131 finished with values: [0.6415094339622641, 0.0, 0.6792452830188679] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'raw', 'rule_variant': 'alternative_empHQ_fixed2', 'n_components': 12, 'alpha': 0.05, 'position_dilation_radius': 2}.
# [I 2026-07-16 10:37:27,742] Trial 132 finished with values: [0.49056603773584906, 0.0, 0.7547169811320756] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'snv_sg_smooth', 'rule_variant': 'alternative_empHQ_fixed2', 'n_components': 7, 'alpha': 0.01, 'sg_window_length': 9, 'sg_polyorder': 2, 'position_dilation_radius': 2}.
# [I 2026-07-16 10:37:34,422] Trial 133 finished with values: [0.018867924528301886, 0.9454545454545454, 0.5178387650085763] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'absorbance_snv_sg_d1', 'rule_variant': 'data_driven_emp_cv', 'n_components': 5, 'alpha': 0.01, 'sg_window_length': 7, 'sg_polyorder': 2, 'position_dilation_radius': 5}.
# [I 2026-07-16 10:37:41,620] Trial 134 finished with values: [0.6981132075471698, 0.0, 0.6509433962264151] and parameters: {'matrix_method': 'object_median', 'preprocessing': 'absorbance_snv_sg_d1', 'rule_variant': 'alternative_chi2_fixed2', 'n_components': 6, 'alpha': 0.05, 'sg_window_length': 9, 'sg_polyorder': 2, 'position_dilation_radius': 3}.
# [I 2026-07-16 10:37:47,936] Trial 135 finished with values: [0.5094339622641509, 0.0, 0.7452830188679244] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'snv_sg_smooth', 'rule_variant': 'alternative_empHQ_emp_cv', 'n_components': 4, 'alpha': 0.01, 'sg_window_length': 13, 'sg_polyorder': 2, 'position_dilation_radius': 2}.
# [I 2026-07-16 10:37:54,088] Trial 136 finished with values: [0.16981132075471697, 0.6545454545454545, 0.5878216123499143] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'snv_sg_smooth', 'rule_variant': 'alternative_chi2_emp_cv', 'n_components': 10, 'alpha': 0.01, 'sg_window_length': 7, 'sg_polyorder': 2, 'position_dilation_radius': 2}.
# [I 2026-07-16 10:38:00,186] Trial 137 finished with values: [0.49056603773584906, 0.12727272727272726, 0.6910806174957118] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'sg_smooth', 'rule_variant': 'alternative_empHQ_fixed2', 'n_components': 3, 'alpha': 0.01, 'sg_window_length': 7, 'sg_polyorder': 2, 'position_dilation_radius': 2}.
# [I 2026-07-16 10:38:06,592] Trial 138 finished with values: [1.0, 0.0, 0.5] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'absorbance_sg_d2', 'rule_variant': 'alternative_chi2_emp_cv', 'n_components': 10, 'alpha': 0.05, 'sg_window_length': 7, 'sg_polyorder': 2, 'position_dilation_radius': 4}.
# [I 2026-07-16 10:38:13,287] Trial 139 finished with values: [1.0, 0.0, 0.5] and parameters: {'matrix_method': 'object_mean', 'preprocessing': 'absorbance_sg_d2', 'rule_variant': 'simple_emp_cv', 'n_components': 7, 'alpha': 0.05, 'sg_window_length': 9, 'sg_polyorder': 2, 'position_dilation_radius': 2}.
# ...
# [I 2026-07-16 11:20:52,188] Trial 292 finished with values: [0.0, 1.0, 0.5] and parameters: {'matrix_method': 'balanced_pixels', 'preprocessing': 'absorbance_snv_sg_d1', 'rule_variant': 'combined_index_chi2', 'n_components': 6, 'alpha': 0.01, 'm': 60, 'balanced_pixel_strategy': 'center', 'sg_window_length': 11, 'sg_polyorder': 2, 'position_dilation_radius': 4}.
# [I 2026-07-16 11:21:01,582] Trial 293 finished with values: [0.0, 0.9393939393939393, 0.5303030303030303] and parameters: {'matrix_method': 'balanced_pixels', 'preprocessing': 'absorbance_sg_d2', 'rule_variant': 'simple_emp_cv', 'n_components': 12, 'alpha': 0.01, 'm': 60, 'balanced_pixel_strategy': 'random', 'sg_window_length': 9, 'sg_polyorder': 2, 'position_dilation_radius': 3}.
# [I 2026-07-16 11:21:11,636] Trial 294 finished with values: [0.0, 0.8121212121212121, 0.5939393939393939] and parameters: {'matrix_method': 'balanced_pixels', 'preprocessing': 'absorbance_sg_d2', 'rule_variant': 'alternative_empHQ_emp_cv', 'n_components': 11, 'alpha': 0.01, 'm': 80, 'balanced_pixel_strategy': 'random', 'sg_window_length': 7, 'sg_polyorder': 2, 'position_dilation_radius': 3}.
# [I 2026-07-16 11:21:19,281] Trial 295 finished with values: [0.0, 0.8606060606060605, 0.5696969696969697] and parameters: {'matrix_method': 'balanced_pixels', 'preprocessing': 'raw', 'rule_variant': 'data_driven_emp_cv', 'n_components': 6, 'alpha': 0.01, 'm': 40, 'balanced_pixel_strategy': 'random', 'position_dilation_radius': 4}.
# [I 2026-07-16 11:21:30,622] Trial 296 finished with values: [0.0, 0.8363636363636363, 0.5818181818181818] and parameters: {'matrix_method': 'balanced_pixels', 'preprocessing': 'snv_sg_smooth', 'rule_variant': 'data_driven_emp_cv', 'n_components': 5, 'alpha': 0.05, 'm': 80, 'balanced_pixel_strategy': 'center', 'sg_window_length': 15, 'sg_polyorder': 2, 'position_dilation_radius': 3}.
# [I 2026-07-16 11:21:38,807] Trial 297 finished with values: [0.0, 0.9818181818181818, 0.509090909090909] and parameters: {'matrix_method': 'balanced_pixels', 'preprocessing': 'raw', 'rule_variant': 'combined_index_chi2', 'n_components': 8, 'alpha': 0.05, 'm': 60, 'balanced_pixel_strategy': 'random', 'position_dilation_radius': 2}.
# [I 2026-07-16 11:21:48,066] Trial 298 finished with values: [0.0, 0.9090909090909091, 0.5454545454545454] and parameters: {'matrix_method': 'balanced_pixels', 'preprocessing': 'absorbance_snv_sg_d1', 'rule_variant': 'alternative_empHQ_fixed2', 'n_components': 5, 'alpha': 0.05, 'm': 40, 'balanced_pixel_strategy': 'center', 'sg_window_length': 13, 'sg_polyorder': 2, 'position_dilation_radius': 2}.
# [I 2026-07-16 11:21:55,851] Trial 299 finished with values: [0.0, 0.9393939393939393, 0.5303030303030303] and parameters: {'matrix_method': 'balanced_pixels', 'preprocessing': 'snv_sg_smooth', 'rule_variant': 'simple_chi2', 'n_components': 4, 'alpha': 0.01, 'm': 20, 'balanced_pixel_strategy': 'random', 'sg_window_length': 11, 'sg_polyorder': 2, 'position_dilation_radius': 5}.
# Trials: (300, 32)
# Completed: (300, 32)
# Saved: C:\Users\alixg\OneDrive - Université Paris-Dauphine\hsi_nuts\results\04B2_optuna_challenge_non_noisy_all\optuna_trials_pixel_matrix.parquet
# All Optuna trials: (500, 32)
# All completed trials: (500, 32)
#     number     state   value_0   value_1   value_2  objective_fn_rate_max  \
# 0       81  COMPLETE  0.000000  0.927273  0.536364               0.000000
# 1      143  COMPLETE  0.000000  0.927273  0.536364               0.000000
# 2      148  COMPLETE  0.000000  0.927273  0.536364               0.000000
# 3      149  COMPLETE  0.000000  0.927273  0.536364               0.000000
# 4       36  COMPLETE  0.000000  0.963636  0.518182               0.000000
# 5       64  COMPLETE  0.000000  0.963636  0.518182               0.000000
# 6       76  COMPLETE  0.000000  0.963636  0.518182               0.000000
# 7      145  COMPLETE  0.000000  0.963636  0.518182               0.000000
# 8       91  COMPLETE  0.000000  0.981818  0.509091               0.000000
# 9      108  COMPLETE  0.000000  0.981818  0.509091               0.000000
# 10     122  COMPLETE  0.000000  0.981818  0.509091               0.000000
# 11     147  COMPLETE  0.000000  0.981818  0.509091               0.000000
# 12     186  COMPLETE  0.000000  0.981818  0.509091               0.000000
# 13     187  COMPLETE  0.000000  0.981818  0.509091               0.000000
# 14     184  COMPLETE  0.018868  0.527273  0.726930               0.018868
# 15     185  COMPLETE  0.018868  0.527273  0.726930               0.018868
# 16     173  COMPLETE  0.018868  0.709091  0.636021               0.018868
# 17     174  COMPLETE  0.018868  0.709091  0.636021               0.018868
# 18      79  COMPLETE  0.018868  0.854545  0.563293               0.018868
# 19     155  COMPLETE  0.018868  0.854545  0.563293               0.018868
#
#     objective_fp_rate_mean  objective_balanced_accuracy_mean  value  \
# 0                 0.927273                          0.536364    NaN
# 1                 0.927273                          0.536364    NaN
# 2                 0.927273                          0.536364    NaN
# 3                 0.927273                          0.536364    NaN
# 4                 0.963636                          0.518182    NaN
# 5                 0.963636                          0.518182    NaN
# 6                 0.963636                          0.518182    NaN
# 7                 0.963636                          0.518182    NaN
# 8                 0.981818                          0.509091    NaN
# 9                 0.981818                          0.509091    NaN
# 10                0.981818                          0.509091    NaN
# 11                0.981818                          0.509091    NaN
# 12                0.981818                          0.509091    NaN
# 13                0.981818                          0.509091    NaN
# 14                0.527273                          0.726930    NaN
# 15                0.527273                          0.726930    NaN
# 16                0.709091                          0.636021    NaN
# 17                0.709091                          0.636021    NaN
# 18                0.854545                          0.563293    NaN
# 19                0.854545                          0.563293    NaN
#
#     matrix_method             preprocessing              rule_variant  \
# 0   object_median                 sg_smooth        data_driven_emp_cv
# 1   object_median                 sg_smooth        data_driven_emp_cv
# 2   object_median                 sg_smooth  alternative_empHQ_fixed2
# 3   object_median                 sg_smooth   alternative_chi2_emp_cv
# 4   object_median  absorbance_snv_sg_smooth        data_driven_emp_cv
# 5   object_median                 sg_smooth             simple_emp_cv
# 6   object_median             snv_sg_smooth   alternative_chi2_emp_cv
# 7   object_median             snv_sg_smooth  alternative_empHQ_emp_cv
# 8   object_median             snv_sg_smooth  alternative_empHQ_fixed2
# 9   object_median             snv_sg_smooth        data_driven_emp_cv
# 10  object_median             snv_sg_smooth  alternative_empHQ_fixed2
# 11  object_median                 sg_smooth  alternative_empHQ_emp_cv
# 12  object_median                 sg_smooth             simple_emp_cv
# 13  object_median                       raw        data_driven_emp_cv
# 14  object_median      absorbance_sg_smooth             simple_emp_cv
# 15  object_median      absorbance_sg_smooth             simple_emp_cv
# 16  object_median      absorbance_sg_smooth  alternative_empHQ_emp_cv
# 17  object_median      absorbance_sg_smooth  alternative_empHQ_emp_cv
# 18  object_median                 sg_smooth  alternative_empHQ_emp_cv
# 19  object_median                 sg_smooth  alternative_empHQ_emp_cv
#
#     n_components  alpha  sg_window_length  sg_polyorder  \
# 0              5   0.01                15             2
# 1              5   0.01                15             2
# 2              5   0.01                15             2
# 3              5   0.01                15             2
# 4              4   0.01                15             2
# 5              7   0.01                13             2
# 6              4   0.01                15             2
# 7              5   0.01                15             2
# 8              6   0.01                15             2
# 9              3   0.01                 7             2
# 10             3   0.01                 7             2
# 11            12   0.01                15             2
# 12            10   0.01                13             2
# 13            12   0.01                11             2
# 14             8   0.01                11             2
# 15             8   0.01                11             2
# 16            10   0.01                11             2
# 17            10   0.01                11             2
# 18             5   0.01                15             2
# 19             6   0.01                15             2
#
#     position_dilation_radius  balanced_accuracy_mean balanced_pixel_strategy  \
# 0                          5                0.536364                  random
# 1                          5                0.536364                  random
# 2                          3                0.536364                  random
# 3                          4                0.536364                  random
# 4                          5                0.518182                  random
# 5                          5                0.518182                  random
# 6                          5                0.518182                  random
# 7                          3                0.518182                  random
# 8                          3                0.509091                  random
# 9                          2                0.509091                  random
# 10                         2                0.509091                  random
# 11                         5                0.509091                  random
# 12                         3                0.509091                  random
# 13                         4                0.509091                  random
# 14                         2                0.726930                  random
# 15                         2                0.726930                  random
# 16                         2                0.636021                  random
# 17                         2                0.636021                  random
# 18                         5                0.563293                  random
# 19                         2                0.563293                  random
#
#     fn_rate_max  fn_rate_mean  fn_rate_std  fp_rate_max  fp_rate_mean  \
# 0      0.000000      0.000000          0.0     0.927273      0.927273
# 1      0.000000      0.000000          0.0     0.927273      0.927273
# 2      0.000000      0.000000          0.0     0.927273      0.927273
# 3      0.000000      0.000000          0.0     0.927273      0.927273
# 4      0.000000      0.000000          0.0     0.963636      0.963636
# 5      0.000000      0.000000          0.0     0.963636      0.963636
# 6      0.000000      0.000000          0.0     0.963636      0.963636
# 7      0.000000      0.000000          0.0     0.963636      0.963636
# 8      0.000000      0.000000          0.0     0.981818      0.981818
# 9      0.000000      0.000000          0.0     0.981818      0.981818
# 10     0.000000      0.000000          0.0     0.981818      0.981818
# 11     0.000000      0.000000          0.0     0.981818      0.981818
# 12     0.000000      0.000000          0.0     0.981818      0.981818
# 13     0.000000      0.000000          0.0     0.981818      0.981818
# 14     0.018868      0.018868          0.0     0.527273      0.527273
# 15     0.018868      0.018868          0.0     0.527273      0.527273
# 16     0.018868      0.018868          0.0     0.709091      0.709091
# 17     0.018868      0.018868          0.0     0.709091      0.709091
# 18     0.018868      0.018868          0.0     0.854545      0.854545
# 19     0.018868      0.018868          0.0     0.854545      0.854545
#
#      fp_rate_std   m  matrix_family       model_family  \
# 0   0.000000e+00  40  object_matrix  rule_variant_grid
# 1   0.000000e+00  40  object_matrix  rule_variant_grid
# 2   0.000000e+00  40  object_matrix  rule_variant_grid
# 3   0.000000e+00  40  object_matrix  rule_variant_grid
# 4   1.110223e-16  40  object_matrix  rule_variant_grid
# 5   1.110223e-16  40  object_matrix  rule_variant_grid
# 6   1.110223e-16  40  object_matrix  rule_variant_grid
# 7   1.110223e-16  40  object_matrix  rule_variant_grid
# 8   0.000000e+00  40  object_matrix  rule_variant_grid
# 9   0.000000e+00  40  object_matrix  rule_variant_grid
# 10  0.000000e+00  40  object_matrix  rule_variant_grid
# 11  0.000000e+00  40  object_matrix  rule_variant_grid
# 12  0.000000e+00  40  object_matrix  rule_variant_grid
# 13  0.000000e+00  40  object_matrix  rule_variant_grid
# 14  0.000000e+00  40  object_matrix  rule_variant_grid
# 15  0.000000e+00  40  object_matrix  rule_variant_grid
# 16  0.000000e+00  40  object_matrix  rule_variant_grid
# 17  0.000000e+00  40  object_matrix  rule_variant_grid
# 18  0.000000e+00  40  object_matrix  rule_variant_grid
# 19  0.000000e+00  40  object_matrix  rule_variant_grid
#
#     object_threshold_median       preprocessing_steps    selection_strategy  \
# 0                      0.50                 sg_smooth  optuna_binary_pareto
# 1                      0.50                 sg_smooth  optuna_binary_pareto
# 2                      0.50                 sg_smooth  optuna_binary_pareto
# 3                      0.50                 sg_smooth  optuna_binary_pareto
# 4                      0.55  absorbance+snv+sg_smooth  optuna_binary_pareto
# 5                      0.70                 sg_smooth  optuna_binary_pareto
# 6                      0.55             snv+sg_smooth  optuna_binary_pareto
# 7                      0.55             snv+sg_smooth  optuna_binary_pareto
# 8                      0.50             snv+sg_smooth  optuna_binary_pareto
# 9                      0.55             snv+sg_smooth  optuna_binary_pareto
# 10                     0.55             snv+sg_smooth  optuna_binary_pareto
# 11                     0.50                 sg_smooth  optuna_binary_pareto
# 12                     0.55                 sg_smooth  optuna_binary_pareto
# 13                     0.50                       raw  optuna_binary_pareto
# 14                     0.50      absorbance+sg_smooth  optuna_binary_pareto
# 15                     0.50      absorbance+sg_smooth  optuna_binary_pareto
# 16                     0.50      absorbance+sg_smooth  optuna_binary_pareto
# 17                     0.50      absorbance+sg_smooth  optuna_binary_pareto
# 18                     0.50                 sg_smooth  optuna_binary_pareto
# 19                     0.50                 sg_smooth  optuna_binary_pareto
#
#    matrix_family_study
# 0        object_matrix
# 1        object_matrix
# 2        object_matrix
# 3        object_matrix
# 4        object_matrix
# 5        object_matrix
# 6        object_matrix
# 7        object_matrix
# 8        object_matrix
# 9        object_matrix
# 10       object_matrix
# 11       object_matrix
# 12       object_matrix
# 13       object_matrix
# 14       object_matrix
# 15       object_matrix
# 16       object_matrix
# 17       object_matrix
# 18       object_matrix
# 19       object_matrix

# %%
# ---------------------------------------------------------------------
# Harmonize objective columns for multi-objective Optuna studies
# ---------------------------------------------------------------------

objective_aliases = {
    "fn_rate_max": "value_0",
    "fp_rate_mean": "value_1",
    "balanced_accuracy_mean": "value_2",
}

for target_col, fallback_col in objective_aliases.items():
    if target_col not in optuna_completed_trials_df.columns and fallback_col in optuna_completed_trials_df.columns:
        optuna_completed_trials_df[target_col] = optuna_completed_trials_df[fallback_col]

for col in [
    "fn_rate_max",
    "fn_rate_mean",
    "fn_rate_std",
    "fp_rate_mean",
    "fp_rate_max",
    "fp_rate_std",
    "balanced_accuracy_mean",
    "object_threshold_median",
]:
    if col in optuna_completed_trials_df.columns:
        optuna_completed_trials_df[col] = pd.to_numeric(
            optuna_completed_trials_df[col],
            errors="coerce",
        )

# %%
# ---------------------------------------------------------------------
# Convert completed Optuna trials to Pareto candidate configs
# ---------------------------------------------------------------------

completed = optuna_completed_trials_df.copy()

if len(completed) == 0:
    optuna_pareto_candidates_df = pd.DataFrame()
else:
    # Harmonize objective columns from user_attrs.
    for col in [
        "fn_rate_max",
        "fn_rate_mean",
        "fn_rate_std",
        "fp_rate_mean",
        "fp_rate_max",
        "fp_rate_std",
        "balanced_accuracy_mean",
        "object_threshold_median",
    ]:
        if col in completed.columns:
            completed[col] = pd.to_numeric(completed[col], errors="coerce")

    if "matrix_family" not in completed.columns:
        completed["matrix_family"] = completed["matrix_family_study"]

    optuna_front_df = pareto_front_by_group(
        completed,
        group_cols=["matrix_family"],
        minimize_cols=[
            "fn_rate_max",
            "fp_rate_mean",
            "fn_rate_std",
        ],
        maximize_cols=[
            "balanced_accuracy_mean",
        ],
    )

    optuna_pareto_candidates_df = (
        optuna_front_df
        .sort_values(
            [
                "matrix_family",
                "fn_rate_max",
                "fp_rate_mean",
                "fn_rate_std",
                "balanced_accuracy_mean",
            ],
            ascending=[True, True, True, True, False],
        )
        .groupby("matrix_family", group_keys=False, dropna=False)
        .head(N_OPTUNA_PARETO_PER_FAMILY)
        .reset_index(drop=True)
    )

    optuna_pareto_candidates_df["optuna_trial_number"] = optuna_pareto_candidates_df["number"].astype(int)
    optuna_pareto_candidates_df["selected_config_id"] = [
        f"optuna_{row.matrix_family}_{int(row.optuna_trial_number):04d}"
        for row in optuna_pareto_candidates_df.itertuples()
    ]

    optuna_pareto_candidates_df["selection_split"] = "validation_batch_3"
    optuna_pareto_candidates_df["selection_strategy"] = "04B2_optuna_binary_pareto"
    optuna_pareto_candidates_df["candidate_source"] = "04B2_optuna_challenge"

    # The calibrated binary object threshold from the objective becomes the fixed threshold.
    optuna_pareto_candidates_df["object_threshold"] = optuna_pareto_candidates_df[
        "object_threshold_median"
    ].astype(float)

    # Harmonize rule columns.
    if "rule" not in optuna_pareto_candidates_df.columns and "rule_variant" in optuna_pareto_candidates_df.columns:
        optuna_pareto_candidates_df["rule"] = optuna_pareto_candidates_df["rule_variant"]

    optuna_pareto_candidates_df = ensure_candidate_columns(optuna_pareto_candidates_df)
    optuna_pareto_candidates_df = normalize_simca_rule_columns(optuna_pareto_candidates_df)
    optuna_pareto_candidates_df = fill_selected_config_defaults(
        optuna_pareto_candidates_df,
        default_values={
            "target_class": TARGET_CLASS,
            "non_target_label": NON_TARGET_LABEL,
            "sg_window_length": 11,
            "sg_polyorder": 2,
            "position_dilation_radius": 3,
            "m": 40,
            "alpha": 0.05,
            "object_threshold": 0.75,
        },
    )
    # Optuna trials contain aggregated multi-seed metrics.
    # We materialize canonical columns used by generic scoring helpers.
    OPTUNA_SELECTION_METRIC_ALIASES = {
        "fn_rate": [
            "fn_rate_max",
            "objective_fn_rate_max",
            "value_0",
            "fn_rate_mean",
        ],
        "fp_rate": [
            "fp_rate_mean",
            "objective_fp_rate_mean",
            "value_1",
            "fp_rate_max",
        ],
        "balanced_accuracy": [
            "balanced_accuracy_mean",
            "objective_balanced_accuracy_mean",
            "value_2",
        ],
    }

    optuna_pareto_candidates_df = materialize_selection_metrics(
        optuna_pareto_candidates_df,
        metric_aliases=OPTUNA_SELECTION_METRIC_ALIASES,
        overwrite=True,
        keep_source_columns=True,
    )

    optuna_pareto_candidates_df = add_detection_selection_score(
        optuna_pareto_candidates_df,
        metric_aliases=OPTUNA_SELECTION_METRIC_ALIASES,
        overwrite_metrics=False,
    )

    optuna_pareto_candidates_df = add_reference_selection_scores(
        optuna_pareto_candidates_df,
        metric_aliases=OPTUNA_SELECTION_METRIC_ALIASES,
        overwrite_metrics=False,
        score_prefix="optuna_",
    )

save_parquet(optuna_pareto_candidates_df, OPTUNA_PARETO_CANDIDATES_PATH)

print("Optuna Pareto candidates:", optuna_pareto_candidates_df.shape)
display(
    optuna_pareto_candidates_df[
        [
            col for col in [
                "selected_config_id",
                "matrix_family",
                "matrix_method",
                "preprocessing",
                "selected_rule_name",
                "rule_for_refit",
                "limit_source",
                "n_components",
                "alpha",
                "object_threshold",
                "m",
                "balanced_pixel_strategy",
                "fn_rate_max",
                "fp_rate_mean",
                "fn_rate_std",
                "balanced_accuracy_mean",
            ]
            if col in optuna_pareto_candidates_df.columns
        ]
    ]
)
# Out:
# Optuna Pareto candidates: (21, 67)
#            selected_config_id  matrix_family    matrix_method  \
# 0   optuna_object_matrix_0081  object_matrix    object_median
# 1   optuna_object_matrix_0143  object_matrix    object_median
# 2   optuna_object_matrix_0148  object_matrix    object_median
# 3   optuna_object_matrix_0149  object_matrix    object_median
# 4   optuna_object_matrix_0184  object_matrix    object_median
# 5   optuna_object_matrix_0185  object_matrix    object_median
# 6   optuna_object_matrix_0152  object_matrix    object_median
# 7   optuna_object_matrix_0153  object_matrix    object_median
# 8   optuna_object_matrix_0157  object_matrix    object_median
# 9   optuna_object_matrix_0160  object_matrix    object_median
# 10  optuna_object_matrix_0105  object_matrix      object_mean
# 11  optuna_object_matrix_0106  object_matrix      object_mean
# 12  optuna_object_matrix_0121  object_matrix      object_mean
# 13   optuna_pixel_matrix_0111   pixel_matrix  balanced_pixels
# 14   optuna_pixel_matrix_0112   pixel_matrix  balanced_pixels
# 15   optuna_pixel_matrix_0285   pixel_matrix  balanced_pixels
# 16   optuna_pixel_matrix_0083   pixel_matrix  balanced_pixels
# 17   optuna_pixel_matrix_0084   pixel_matrix  balanced_pixels
# 18   optuna_pixel_matrix_0257   pixel_matrix  balanced_pixels
# 19   optuna_pixel_matrix_0258   pixel_matrix  balanced_pixels
# 20   optuna_pixel_matrix_0273   pixel_matrix  balanced_pixels
#
#                preprocessing        selected_rule_name  \
# 0                  sg_smooth        data_driven_emp_cv
# 1                  sg_smooth        data_driven_emp_cv
# 2                  sg_smooth  alternative_empHQ_fixed2
# 3                  sg_smooth   alternative_chi2_emp_cv
# 4       absorbance_sg_smooth             simple_emp_cv
# 5       absorbance_sg_smooth             simple_emp_cv
# 6           absorbance_sg_d2  alternative_empHQ_emp_cv
# 7           absorbance_sg_d2  alternative_empHQ_emp_cv
# 8                  sg_smooth       combined_index_chi2
# 9                  sg_smooth       combined_index_chi2
# 10             snv_sg_smooth  alternative_empHQ_fixed2
# 11             snv_sg_smooth  alternative_empHQ_fixed2
# 12             snv_sg_smooth  alternative_empHQ_fixed2
# 13      absorbance_sg_smooth          data_driven_chi2
# 14      absorbance_sg_smooth          data_driven_chi2
# 15      absorbance_sg_smooth          data_driven_chi2
# 16                 sg_smooth               simple_chi2
# 17                 sg_smooth               simple_chi2
# 18  absorbance_snv_sg_smooth               simple_chi2
# 19  absorbance_snv_sg_smooth               simple_chi2
# 20          absorbance_sg_d2               simple_chi2
#
#               rule_for_refit  limit_source  n_components  alpha  \
# 0         data_driven_emp_cv  empirical_cv             5   0.01
# 1         data_driven_emp_cv  empirical_cv             5   0.01
# 2   alternative_empHQ_fixed2          chi2             5   0.01
# 3    alternative_chi2_emp_cv  empirical_cv             5   0.01
# 4              simple_emp_cv  empirical_cv             8   0.01
# 5              simple_emp_cv  empirical_cv             8   0.01
# 6   alternative_empHQ_emp_cv  empirical_cv             7   0.01
# 7   alternative_empHQ_emp_cv  empirical_cv             7   0.01
# 8        combined_index_chi2   scaled_chi2             3   0.01
# 9        combined_index_chi2   scaled_chi2             3   0.01
# 10  alternative_empHQ_fixed2          chi2             3   0.01
# 11  alternative_empHQ_fixed2          chi2             3   0.01
# 12  alternative_empHQ_fixed2          chi2             3   0.01
# 13          data_driven_chi2          chi2             7   0.01
# 14          data_driven_chi2          chi2             7   0.01
# 15          data_driven_chi2          chi2             7   0.01
# 16               simple_chi2          chi2             6   0.05
# 17               simple_chi2          chi2             6   0.05
# 18               simple_chi2          chi2             6   0.05
# 19               simple_chi2          chi2             6   0.05
# 20               simple_chi2          chi2            10   0.05
#
#     object_threshold   m balanced_pixel_strategy  fn_rate_max  fp_rate_mean  \
# 0               0.50  40                  random     0.000000      0.927273
# 1               0.50  40                  random     0.000000      0.927273
# 2               0.50  40                  random     0.000000      0.927273
# 3               0.50  40                  random     0.000000      0.927273
# 4               0.50  40                  random     0.018868      0.527273
# 5               0.50  40                  random     0.018868      0.527273
# 6               0.50  40                  random     0.150943      0.418182
# 7               0.50  40                  random     0.150943      0.418182
# 8               0.50  40                  random     0.207547      0.400000
# 9               0.50  40                  random     0.207547      0.400000
# 10              0.55  40                  random     0.264151      0.000000
# 11              0.55  40                  random     0.264151      0.000000
# 12              0.55  40                  random     0.264151      0.000000
# 13              0.75  80                  center     0.000000      0.200000
# 14              0.75  80                  center     0.000000      0.200000
# 15              0.60  40                  center     0.000000      0.200000
# 16              0.55  20                  random     0.037736      0.193939
# 17              0.55  20                  random     0.037736      0.193939
# 18              0.55  80                  center     0.056604      0.036364
# 19              0.55  80                  center     0.056604      0.036364
# 20              0.50  20                  center     0.603774      0.036364
#
#      fn_rate_std  balanced_accuracy_mean
# 0   0.000000e+00                0.536364
# 1   0.000000e+00                0.536364
# 2   0.000000e+00                0.536364
# 3   0.000000e+00                0.536364
# 4   0.000000e+00                0.726930
# 5   0.000000e+00                0.726930
# 6   0.000000e+00                0.715437
# 7   0.000000e+00                0.715437
# 8   2.775558e-17                0.696226
# 9   2.775558e-17                0.696226
# 10  0.000000e+00                0.867925
# 11  0.000000e+00                0.867925
# 12  0.000000e+00                0.867925
# 13  0.000000e+00                0.900000
# 14  0.000000e+00                0.900000
# 15  0.000000e+00                0.900000
# 16  0.000000e+00                0.884162
# 17  0.000000e+00                0.884162
# 18  6.938894e-18                0.953516
# 19  6.938894e-18                0.953516
# 20  0.000000e+00                0.679931

# %%
plot_detection_pareto(
    optuna_pareto_candidates_df,
    fn_col="fn_rate",
    fp_col="fp_rate",
    color_col="balanced_accuracy",
    symbol_col="matrix_family",
    id_col="selected_config_id",
    group_col="matrix_family",
    title="Optuna challengers — validation Pareto front",
    show=True,
)

# %%
# ---------------------------------------------------------------------
# Refit Optuna Pareto candidates on validation batch 3
# ---------------------------------------------------------------------

if len(optuna_pareto_candidates_df) == 0:
    optuna_validation_refit_metrics_df = pd.DataFrame()
    optuna_validation_refit_objects_df = pd.DataFrame()
    optuna_validation_refit_pixels_df = pd.DataFrame()
    optuna_validation_pixel_errors_by_image_df = pd.DataFrame()
    optuna_validation_refit_errors_df = pd.DataFrame()
    print("No Optuna candidate to refit.")

else:
    # Optional: limit refit per family to avoid too much runtime.
    optuna_refit_candidates_df = (
        optuna_pareto_candidates_df
        .sort_values(
            [
                "matrix_family",
                "fn_rate_max",
                "fp_rate_mean",
                "fn_rate_std",
                "balanced_accuracy_mean",
            ],
            ascending=[True, True, True, True, False],
        )
        .groupby("matrix_family", group_keys=False, dropna=False)
        .head(N_OPTUNA_REFIT_PER_FAMILY)
        .reset_index(drop=True)
    )

    (
        optuna_validation_refit_metrics_df,
        optuna_validation_refit_objects_df,
        optuna_validation_refit_pixels_df,
        optuna_validation_pixel_errors_by_image_df,
        optuna_validation_refit_errors_df,
    ) = refit_selected_simca_configs(
        selected_configs_df=optuna_refit_candidates_df,
        object_db=object_db,
        image_db=image_db,
        train_filters=TRAIN_FILTERS,
        projection_filters=VALIDATION_FILTERS,
        preprocessing_configs=PREPROCESSING_CONFIGS,
        evaluation_split="validation_batch_3_optuna_refit",
        wavelengths=wavelengths,
        random_state=RANDOM_STATE,
        replace=REPLACE_BALANCED_PIXELS,
        cv_n_splits=CV_N_SPLITS,
        cv_group_col=CV_GROUP_COL,
        target_class=TARGET_CLASS,
        non_target_label=NON_TARGET_LABEL,
    )

    optuna_validation_refit_objects_df = add_binary_confusion_case(
        optuna_validation_refit_objects_df,
        target_class=TARGET_CLASS,
        level="object",
    )

    optuna_validation_refit_pixels_df = add_binary_confusion_case(
        optuna_validation_refit_pixels_df,
        target_class=TARGET_CLASS,
        level="pixel",
    )

save_parquet(optuna_validation_refit_metrics_df, OPTUNA_VALIDATION_REFIT_METRICS_PATH)
save_parquet_if_nonempty(optuna_validation_refit_objects_df, OPTUNA_VALIDATION_REFIT_OBJECTS_PATH)
save_parquet_if_nonempty(optuna_validation_refit_pixels_df, OPTUNA_VALIDATION_REFIT_PIXELS_PATH)
save_parquet_if_nonempty(optuna_validation_pixel_errors_by_image_df, OPTUNA_VALIDATION_PIXEL_ERRORS_BY_IMAGE_PATH)
save_parquet_if_nonempty(optuna_validation_refit_errors_df, OPTUNA_VALIDATION_REFIT_ERRORS_PATH)

print("Optuna validation refit metrics:", optuna_validation_refit_metrics_df.shape)
print("Optuna validation refit errors:", optuna_validation_refit_errors_df.shape)

display(optuna_validation_refit_metrics_df.head())
display(optuna_validation_refit_errors_df)
# Out:
# [validation_batch_3_optuna_refit] optuna_object_matrix_0081
# [validation_batch_3_optuna_refit] optuna_object_matrix_0143
# [validation_batch_3_optuna_refit] optuna_object_matrix_0148
# [validation_batch_3_optuna_refit] optuna_object_matrix_0149
# [validation_batch_3_optuna_refit] optuna_object_matrix_0184
# [validation_batch_3_optuna_refit] optuna_object_matrix_0185
# [validation_batch_3_optuna_refit] optuna_object_matrix_0152
# [validation_batch_3_optuna_refit] optuna_object_matrix_0153
# [validation_batch_3_optuna_refit] optuna_object_matrix_0157
# [validation_batch_3_optuna_refit] optuna_object_matrix_0160
# [validation_batch_3_optuna_refit] optuna_object_matrix_0105
# [validation_batch_3_optuna_refit] optuna_object_matrix_0106
# [validation_batch_3_optuna_refit] optuna_object_matrix_0121
# [validation_batch_3_optuna_refit] optuna_pixel_matrix_0111
# [validation_batch_3_optuna_refit] optuna_pixel_matrix_0112
# [validation_batch_3_optuna_refit] optuna_pixel_matrix_0285
# [validation_batch_3_optuna_refit] optuna_pixel_matrix_0083
# [validation_batch_3_optuna_refit] optuna_pixel_matrix_0084
# [validation_batch_3_optuna_refit] optuna_pixel_matrix_0257
# [validation_batch_3_optuna_refit] optuna_pixel_matrix_0258
# [validation_batch_3_optuna_refit] optuna_pixel_matrix_0273
# Optuna validation refit metrics: (21, 76)
# Optuna validation refit errors: (0, 0)
#    number     state   value_0   value_1   value_2  objective_fn_rate_max  \
# 0      81  COMPLETE  0.000000  0.927273  0.536364               0.000000
# 1     143  COMPLETE  0.000000  0.927273  0.536364               0.000000
# 2     148  COMPLETE  0.000000  0.927273  0.536364               0.000000
# 3     149  COMPLETE  0.000000  0.927273  0.536364               0.000000
# 4     184  COMPLETE  0.018868  0.527273  0.726930               0.018868
#
#    objective_fp_rate_mean  objective_balanced_accuracy_mean  value  \
# 0                0.927273                          0.536364    NaN
# 1                0.927273                          0.536364    NaN
# 2                0.927273                          0.536364    NaN
# 3                0.927273                          0.536364    NaN
# 4                0.527273                          0.726930    NaN
#
#    matrix_method         preprocessing              rule_variant  \
# 0  object_median             sg_smooth        data_driven_emp_cv
# 1  object_median             sg_smooth        data_driven_emp_cv
# 2  object_median             sg_smooth  alternative_empHQ_fixed2
# 3  object_median             sg_smooth   alternative_chi2_emp_cv
# 4  object_median  absorbance_sg_smooth             simple_emp_cv
#
#    n_components  alpha  sg_window_length  sg_polyorder  \
# 0             5   0.01                15             2
# 1             5   0.01                15             2
# 2             5   0.01                15             2
# 3             5   0.01                15             2
# 4             8   0.01                11             2
#
#    position_dilation_radius  balanced_accuracy_mean balanced_pixel_strategy  \
# 0                         5                0.536364                  random
# 1                         5                0.536364                  random
# 2                         3                0.536364                  random
# 3                         4                0.536364                  random
# 4                         2                0.726930                  random
#
#    fn_rate_max  fn_rate_mean  fn_rate_std  fp_rate_max  fp_rate_mean  \
# 0     0.000000      0.000000          0.0     0.927273      0.927273
# 1     0.000000      0.000000          0.0     0.927273      0.927273
# 2     0.000000      0.000000          0.0     0.927273      0.927273
# 3     0.000000      0.000000          0.0     0.927273      0.927273
# 4     0.018868      0.018868          0.0     0.527273      0.527273
#
#    fp_rate_std   m  matrix_family       model_family  object_threshold_median  \
# 0          0.0  40  object_matrix  rule_variant_grid                      0.5
# 1          0.0  40  object_matrix  rule_variant_grid                      0.5
# 2          0.0  40  object_matrix  rule_variant_grid                      0.5
# 3          0.0  40  object_matrix  rule_variant_grid                      0.5
# 4          0.0  40  object_matrix  rule_variant_grid                      0.5
#
#     preprocessing_steps         selection_strategy matrix_family_study  \
# 0             sg_smooth  04B2_optuna_binary_pareto       object_matrix
# 1             sg_smooth  04B2_optuna_binary_pareto       object_matrix
# 2             sg_smooth  04B2_optuna_binary_pareto       object_matrix
# 3             sg_smooth  04B2_optuna_binary_pareto       object_matrix
# 4  absorbance+sg_smooth  04B2_optuna_binary_pareto       object_matrix
#
#    optuna_trial_number         selected_config_id     selection_split  \
# 0                   81  optuna_object_matrix_0081  validation_batch_3
# 1                  143  optuna_object_matrix_0143  validation_batch_3
# 2                  148  optuna_object_matrix_0148  validation_batch_3
# 3                  149  optuna_object_matrix_0149  validation_batch_3
# 4                  184  optuna_object_matrix_0184  validation_batch_3
#
#         candidate_source  object_threshold         rule training_matrix_id  \
# 0  04B2_optuna_challenge               0.5  data_driven      object_median
# 1  04B2_optuna_challenge               0.5  data_driven      object_median
# 2  04B2_optuna_challenge               0.5  alternative      object_median
# 3  04B2_optuna_challenge               0.5  alternative      object_median
# 4  04B2_optuna_challenge               0.5       simple      object_median
#
#          selected_rule_name            rule_for_refit  \
# 0        data_driven_emp_cv        data_driven_emp_cv
# 1        data_driven_emp_cv        data_driven_emp_cv
# 2  alternative_empHQ_fixed2  alternative_empHQ_fixed2
# 3   alternative_chi2_emp_cv   alternative_chi2_emp_cv
# 4             simple_emp_cv             simple_emp_cv
#
#               rule_original     rule_variant_original  \
# 0        data_driven_emp_cv        data_driven_emp_cv
# 1        data_driven_emp_cv        data_driven_emp_cv
# 2  alternative_empHQ_fixed2  alternative_empHQ_fixed2
# 3   alternative_chi2_emp_cv   alternative_chi2_emp_cv
# 4             simple_emp_cv             simple_emp_cv
#
#                  rule_token  limit_source target_class non_target_label  \
# 0        data_driven_emp_cv  empirical_cv       peanut           almond
# 1        data_driven_emp_cv  empirical_cv       peanut           almond
# 2  alternative_empHQ_fixed2          chi2       peanut           almond
# 3   alternative_chi2_emp_cv  empirical_cv       peanut           almond
# 4             simple_emp_cv  empirical_cv       peanut           almond
#
#     fn_rate fn_rate_source   fp_rate fp_rate_source  balanced_accuracy  \
# 0  0.000000    fn_rate_max  0.927273   fp_rate_mean           0.536364
# 1  0.000000    fn_rate_max  0.927273   fp_rate_mean           0.536364
# 2  0.000000    fn_rate_max  0.927273   fp_rate_mean           0.536364
# 3  0.000000    fn_rate_max  0.927273   fp_rate_mean           0.536364
# 4  0.018868    fn_rate_max  0.527273   fp_rate_mean           0.726930
#
#   balanced_accuracy_source  target_sensitivity target_sensitivity_source  \
# 0   balanced_accuracy_mean            1.000000                      None
# 1   balanced_accuracy_mean            1.000000                      None
# 2   balanced_accuracy_mean            1.000000                      None
# 3   balanced_accuracy_mean            1.000000                      None
# 4   balanced_accuracy_mean            0.981132                      None
#
#    non_target_specificity non_target_specificity_source  f1_score  \
# 0                0.072727                          None  0.675159
# 1                0.072727                          None  0.675159
# 2                0.072727                          None  0.675159
# 3                0.072727                          None  0.675159
# 4                0.472727                          None  0.776119
#
#   f1_score_source  accuracy accuracy_source  precision precision_source  \
# 0            None  0.527778            None   0.509615             None
# 1            None  0.527778            None   0.509615             None
# 2            None  0.527778            None   0.509615             None
# 3            None  0.527778            None   0.509615             None
# 4            None  0.722222            None   0.641975             None
#
#    selection_score  optuna_score_conservative_target  \
# 0        -0.927273                         -1.318182
# 1        -0.927273                         -1.318182
# 2        -0.927273                         -1.318182
# 3        -0.927273                         -1.318182
# 4        -0.715952                         -0.704974
#
#    optuna_score_balanced_reference  optuna_score_specificity_control  \
# 0                         0.681818                         -2.563636
# 1                         0.681818                         -2.563636
# 2                         0.681818                         -2.563636
# 3                         0.681818                         -2.563636
# 4                         1.596913                         -0.257976
#
#   non_target_class    n  tp  fn  fp  tn                 evaluation_split  \
# 0           almond  108  53   0  51   4  validation_batch_3_optuna_refit
# 1           almond  108  53   0  51   4  validation_batch_3_optuna_refit
# 2           almond  108  53   0  51   4  validation_batch_3_optuna_refit
# 3           almond  108  53   0  51   4  validation_batch_3_optuna_refit
# 4           almond  108  52   1  29  26  validation_batch_3_optuna_refit
#
#    n_projected_objects  n_projected_pixels
# 0                  108                6812
# 1                  108                6812
# 2                  108                6812
# 3                  108                6812
# 4                  108                6812
# Empty DataFrame
# Columns: []
# Index: []

# %%
# ---------------------------------------------------------------------
# Calibrate 3-way thresholds for Optuna challengers on validation batch 3
# ---------------------------------------------------------------------

if len(optuna_validation_refit_objects_df) == 0:
    optuna_three_way_grid_df = pd.DataFrame()
    optuna_three_way_selected_thresholds_df = pd.DataFrame()
    optuna_validation_3way_metrics_df = pd.DataFrame()
    optuna_validation_3way_objects_df = pd.DataFrame()
    optuna_challengers_df = pd.DataFrame()

else:
    optuna_three_way_grid_df, optuna_three_way_selected_thresholds_df = calibrate_three_way_thresholds_by_config(
        object_df=optuna_validation_refit_objects_df,
        config_cols=["selected_config_id"],
        target_class=TARGET_CLASS,
        non_target_label=NON_TARGET_LABEL,
        lower_thresholds=THREE_WAY_LOWER_THRESHOLDS,
        upper_thresholds=THREE_WAY_UPPER_THRESHOLDS,
        max_target_miss_rate=MAX_THREE_WAY_TARGET_MISS_RATE,
        max_false_accept_rate=MAX_THREE_WAY_FALSE_ACCEPT_RATE,
        max_uncertain_rate=MAX_THREE_WAY_UNCERTAIN_RATE,
    )

    optuna_validation_3way_metrics_df, optuna_validation_3way_objects_df = evaluate_three_way_by_config(
        object_df=optuna_validation_refit_objects_df,
        thresholds_df=optuna_three_way_selected_thresholds_df,
        config_id_col="selected_config_id",
        target_class=TARGET_CLASS,
        non_target_label=NON_TARGET_LABEL,
    )

    optuna_challengers_df = optuna_pareto_candidates_df.merge(
        optuna_three_way_selected_thresholds_df[
            [
                "selected_config_id",
                "three_way_lower_threshold",
                "three_way_upper_threshold",
                "target_miss_rate",
                "screening_sensitivity",
                "non_target_false_accept_rate",
                "uncertain_rate",
                "coverage_rate",
            ]
        ].rename(
            columns={
                "target_miss_rate": "validation_3way_target_miss_rate",
                "screening_sensitivity": "validation_3way_screening_sensitivity",
                "non_target_false_accept_rate": "validation_3way_non_target_false_accept_rate",
                "uncertain_rate": "validation_3way_uncertain_rate",
                "coverage_rate": "validation_3way_coverage_rate",
            }
        ),
        on="selected_config_id",
        how="inner",
    )

    # Add refit binary metrics from validation.
    refit_cols = [
        "selected_config_id",
        "balanced_accuracy",
        "target_sensitivity",
        "non_target_specificity",
        "fn_rate",
        "fp_rate",
        "f1_score",
        "accuracy",
        "precision",
    ]
    refit_cols = [
        col for col in refit_cols
        if col in optuna_validation_refit_metrics_df.columns
    ]

    optuna_challengers_df = optuna_challengers_df.merge(
        optuna_validation_refit_metrics_df[refit_cols].rename(
            columns={
                "balanced_accuracy": "validation_balanced_accuracy",
                "target_sensitivity": "validation_target_sensitivity",
                "non_target_specificity": "validation_non_target_specificity",
                "fn_rate": "validation_fn_rate",
                "fp_rate": "validation_fp_rate",
                "f1_score": "validation_f1_score",
                "accuracy": "validation_accuracy",
                "precision": "validation_precision",
            }
        ),
        on="selected_config_id",
        how="left",
    )

    optuna_challengers_df["candidate_source"] = "04B2_optuna_challenge"
    optuna_challengers_df["selection_strategy"] = (
        optuna_challengers_df["selection_strategy"].astype(str)
        + "__3way_calibrated"
    )

save_parquet_if_nonempty(optuna_three_way_grid_df, OPTUNA_THREE_WAY_GRID_PATH)
save_parquet_if_nonempty(optuna_three_way_selected_thresholds_df, OPTUNA_THREE_WAY_SELECTED_PATH)
save_parquet_if_nonempty(optuna_validation_3way_objects_df, OPTUNA_VALIDATION_3WAY_OBJECTS_PATH)
save_parquet_if_nonempty(optuna_validation_3way_metrics_df, OPTUNA_VALIDATION_3WAY_METRICS_PATH)
save_parquet_if_nonempty(optuna_challengers_df, OPTUNA_CHALLENGERS_FOR_04C_PATH)

print("Optuna 3-way grid:", optuna_three_way_grid_df.shape)
print("Optuna selected 3-way thresholds:", optuna_three_way_selected_thresholds_df.shape)
print("Optuna challengers for 04C:", optuna_challengers_df.shape)

display(
    optuna_challengers_df[
        [
            col for col in [
                "selected_config_id",
                "matrix_family",
                "matrix_method",
                "preprocessing",
                "selected_rule_name",
                "n_components",
                "alpha",
                "object_threshold",
                "three_way_lower_threshold",
                "three_way_upper_threshold",
                "validation_fn_rate",
                "validation_fp_rate",
                "validation_3way_target_miss_rate",
                "validation_3way_non_target_false_accept_rate",
                "validation_3way_uncertain_rate",
                "validation_3way_coverage_rate",
            ]
            if col in optuna_challengers_df.columns
        ]
    ]
)
# Out:
# Optuna 3-way grid: (2394, 23)
# Optuna selected 3-way thresholds: (21, 23)
# Optuna challengers for 04C: (21, 82)
#            selected_config_id  matrix_family    matrix_method  \
# 0   optuna_object_matrix_0081  object_matrix    object_median
# 1   optuna_object_matrix_0143  object_matrix    object_median
# 2   optuna_object_matrix_0148  object_matrix    object_median
# 3   optuna_object_matrix_0149  object_matrix    object_median
# 4   optuna_object_matrix_0184  object_matrix    object_median
# 5   optuna_object_matrix_0185  object_matrix    object_median
# 6   optuna_object_matrix_0152  object_matrix    object_median
# 7   optuna_object_matrix_0153  object_matrix    object_median
# 8   optuna_object_matrix_0157  object_matrix    object_median
# 9   optuna_object_matrix_0160  object_matrix    object_median
# 10  optuna_object_matrix_0105  object_matrix      object_mean
# 11  optuna_object_matrix_0106  object_matrix      object_mean
# 12  optuna_object_matrix_0121  object_matrix      object_mean
# 13   optuna_pixel_matrix_0111   pixel_matrix  balanced_pixels
# 14   optuna_pixel_matrix_0112   pixel_matrix  balanced_pixels
# 15   optuna_pixel_matrix_0285   pixel_matrix  balanced_pixels
# 16   optuna_pixel_matrix_0083   pixel_matrix  balanced_pixels
# 17   optuna_pixel_matrix_0084   pixel_matrix  balanced_pixels
# 18   optuna_pixel_matrix_0257   pixel_matrix  balanced_pixels
# 19   optuna_pixel_matrix_0258   pixel_matrix  balanced_pixels
# 20   optuna_pixel_matrix_0273   pixel_matrix  balanced_pixels
#
#                preprocessing        selected_rule_name  n_components  alpha  \
# 0                  sg_smooth        data_driven_emp_cv             5   0.01
# 1                  sg_smooth        data_driven_emp_cv             5   0.01
# 2                  sg_smooth  alternative_empHQ_fixed2             5   0.01
# 3                  sg_smooth   alternative_chi2_emp_cv             5   0.01
# 4       absorbance_sg_smooth             simple_emp_cv             8   0.01
# 5       absorbance_sg_smooth             simple_emp_cv             8   0.01
# 6           absorbance_sg_d2  alternative_empHQ_emp_cv             7   0.01
# 7           absorbance_sg_d2  alternative_empHQ_emp_cv             7   0.01
# 8                  sg_smooth       combined_index_chi2             3   0.01
# 9                  sg_smooth       combined_index_chi2             3   0.01
# 10             snv_sg_smooth  alternative_empHQ_fixed2             3   0.01
# 11             snv_sg_smooth  alternative_empHQ_fixed2             3   0.01
# 12             snv_sg_smooth  alternative_empHQ_fixed2             3   0.01
# 13      absorbance_sg_smooth          data_driven_chi2             7   0.01
# 14      absorbance_sg_smooth          data_driven_chi2             7   0.01
# 15      absorbance_sg_smooth          data_driven_chi2             7   0.01
# 16                 sg_smooth               simple_chi2             6   0.05
# 17                 sg_smooth               simple_chi2             6   0.05
# 18  absorbance_snv_sg_smooth               simple_chi2             6   0.05
# 19  absorbance_snv_sg_smooth               simple_chi2             6   0.05
# 20          absorbance_sg_d2               simple_chi2            10   0.05
#
#     object_threshold  three_way_lower_threshold  three_way_upper_threshold  \
# 0               0.50                       0.50                       0.95
# 1               0.50                       0.50                       0.95
# 2               0.50                       0.50                       0.95
# 3               0.50                       0.50                       0.95
# 4               0.50                       0.30                       0.70
# 5               0.50                       0.30                       0.70
# 6               0.50                       0.25                       0.65
# 7               0.50                       0.25                       0.65
# 8               0.50                       0.05                       0.65
# 9               0.50                       0.05                       0.65
# 10              0.55                       0.15                       0.55
# 11              0.55                       0.15                       0.55
# 12              0.55                       0.15                       0.55
# 13              0.75                       0.60                       0.95
# 14              0.75                       0.60                       0.95
# 15              0.60                       0.60                       0.95
# 16              0.55                       0.30                       0.95
# 17              0.55                       0.30                       0.95
# 18              0.55                       0.40                       0.65
# 19              0.55                       0.40                       0.65
# 20              0.50                       0.05                       0.50
#
#     validation_fn_rate  validation_fp_rate  validation_3way_target_miss_rate  \
# 0             0.000000            0.927273                          0.000000
# 1             0.000000            0.927273                          0.000000
# 2             0.000000            0.927273                          0.000000
# 3             0.000000            0.927273                          0.000000
# 4             0.018868            0.527273                          0.000000
# 5             0.018868            0.527273                          0.000000
# 6             0.150943            0.418182                          0.000000
# 7             0.150943            0.418182                          0.000000
# 8             0.207547            0.400000                          0.000000
# 9             0.207547            0.400000                          0.000000
# 10            0.264151            0.000000                          0.000000
# 11            0.264151            0.000000                          0.000000
# 12            0.264151            0.000000                          0.000000
# 13            0.000000            0.200000                          0.000000
# 14            0.000000            0.200000                          0.000000
# 15            0.000000            0.200000                          0.000000
# 16            0.037736            0.181818                          0.000000
# 17            0.037736            0.181818                          0.000000
# 18            0.056604            0.036364                          0.000000
# 19            0.056604            0.036364                          0.000000
# 20            1.000000            0.000000                          0.132075
#
#     validation_3way_non_target_false_accept_rate  \
# 0                                       0.290909
# 1                                       0.290909
# 2                                       0.236364
# 3                                       0.345455
# 4                                       0.290909
# 5                                       0.290909
# 6                                       0.290909
# 7                                       0.290909
# 8                                       0.272727
# 9                                       0.272727
# 10                                      0.000000
# 11                                      0.000000
# 12                                      0.000000
# 13                                      0.054545
# 14                                      0.054545
# 15                                      0.000000
# 16                                      0.000000
# 17                                      0.000000
# 18                                      0.000000
# 19                                      0.000000
# 20                                      0.000000
#
#     validation_3way_uncertain_rate  validation_3way_coverage_rate
# 0                         0.546296                       0.453704
# 1                         0.546296                       0.453704
# 2                         0.601852                       0.398148
# 3                         0.509259                       0.490741
# 4                         0.564815                       0.435185
# 5                         0.564815                       0.435185
# 6                         0.500000                       0.500000
# 7                         0.500000                       0.500000
# 8                         0.555556                       0.444444
# 9                         0.555556                       0.444444
# 10                        0.416667                       0.583333
# 11                        0.416667                       0.583333
# 12                        0.416667                       0.583333
# 13                        0.351852                       0.648148
# 14                        0.351852                       0.648148
# 15                        0.407407                       0.592593
# 16                        0.518519                       0.481481
# 17                        0.518519                       0.481481
# 18                        0.074074                       0.925926
# 19                        0.074074                       0.925926
# 20                        0.537037                       0.462963

# %%
optuna_three_way_plot_df = (
    optuna_three_way_grid_df
    .merge(
        optuna_pareto_candidates_df[
            [
                "selected_config_id",
                "matrix_family",
            ]
        ].drop_duplicates(),
        on="selected_config_id",
        how="left",
    )
)

plot_three_way_tradeoff(
    optuna_three_way_plot_df,
    uncertain_col="uncertain_rate",
    miss_col="target_miss_rate",
    false_accept_col="non_target_false_accept_rate",
    coverage_col="coverage_rate",
    group_col="matrix_family",
    id_col="selected_config_id",
    title="Optuna challengers — three-way threshold trade-off",
    show=True,
)

# %%
# ---------------------------------------------------------------------
# Merge 04B robust panel and Optuna challengers for 04C
# ---------------------------------------------------------------------

candidate_parts = []

if INCLUDE_GRID_ROBUST_CANDIDATES and len(robust_grid_candidates_df) > 0:
    grid_for_test_df = robust_grid_candidates_df.copy()
    grid_for_test_df["candidate_source"] = grid_for_test_df.get(
        "candidate_source",
        "04B_grid_robustness",
    )
    candidate_parts.append(grid_for_test_df)

if len(optuna_challengers_df) > 0:
    optuna_for_test_df = optuna_challengers_df.copy()
    optuna_for_test_df["candidate_source"] = "04B2_optuna_challenge"
    candidate_parts.append(optuna_for_test_df)

if candidate_parts:
    candidate_configs_for_pure_test_df = (
        pd.concat(candidate_parts, ignore_index=True, sort=False)
        .drop_duplicates(
            subset=[
                "model_family",
                "matrix_family",
                "training_matrix_id",
                "matrix_method",
                "preprocessing",
                "selected_rule_name",
                "rule_for_refit",
                "n_components",
                "alpha",
                "object_threshold",
                "m",
                "balanced_pixel_strategy",
                "sg_window_length",
                "sg_polyorder",
                "position_dilation_radius",
                "three_way_lower_threshold",
                "three_way_upper_threshold",
            ],
            keep="first",
        )
        .reset_index(drop=True)
    )
else:
    candidate_configs_for_pure_test_df = pd.DataFrame()

candidate_configs_for_pure_test_df = ensure_candidate_columns(candidate_configs_for_pure_test_df)
candidate_configs_for_pure_test_df = normalize_simca_rule_columns(candidate_configs_for_pure_test_df)
candidate_configs_for_pure_test_df = fill_selected_config_defaults(
    candidate_configs_for_pure_test_df,
    default_values={
        "target_class": TARGET_CLASS,
        "non_target_label": NON_TARGET_LABEL,
        "sg_window_length": 11,
        "sg_polyorder": 2,
        "position_dilation_radius": 3,
        "m": 40,
        "alpha": 0.05,
        "object_threshold": 0.75,
    },
)

if len(candidate_configs_for_pure_test_df) > 0 and len(pca_selected_preprocessings_df) > 0:
    candidate_configs_for_pure_test_df = filter_simca_candidates_by_pca_preprocessing(
        candidate_configs_for_pure_test_df,
        pca_selected_preprocessings_df,
        strict=True,
    )

candidate_configs_for_pure_test_df = deduplicate_simca_candidates(
    candidate_configs_for_pure_test_df
)

# Keep families separated in the final display/order.
sort_cols = [
    "matrix_family",
    "candidate_source",
    "validation_fn_rate",
    "validation_fp_rate",
    "validation_3way_target_miss_rate",
    "validation_3way_uncertain_rate",
]

sort_cols = [
    col for col in sort_cols
    if col in candidate_configs_for_pure_test_df.columns
]

ascending = [
    True if col in {"matrix_family", "candidate_source"} else True
    for col in sort_cols
]

candidate_configs_for_pure_test_df = (
    candidate_configs_for_pure_test_df
    .sort_values(sort_cols, ascending=ascending)
    .reset_index(drop=True)
)

# Ensure unique selected_config_id.
if candidate_configs_for_pure_test_df["selected_config_id"].astype(str).duplicated().any():
    candidate_configs_for_pure_test_df["previous_selected_config_id"] = (
        candidate_configs_for_pure_test_df["selected_config_id"].astype(str)
    )
    candidate_configs_for_pure_test_df["selected_config_id"] = [
        f"testcand_{i:03d}" for i in range(len(candidate_configs_for_pure_test_df))
    ]

required_for_04c = [
    "selected_config_id",
    "matrix_family",
    "matrix_method",
    "preprocessing",
    "rule_for_refit",
    "n_components",
    "alpha",
    "object_threshold",
    "three_way_lower_threshold",
    "three_way_upper_threshold",
]

missing_for_04c = [
    col for col in required_for_04c
    if col not in candidate_configs_for_pure_test_df.columns
]

if missing_for_04c:
    raise KeyError(f"Missing required columns for 04C: {missing_for_04c}")

save_parquet(
    candidate_configs_for_pure_test_df,
    CANDIDATE_CONFIGS_FOR_PURE_TEST_PATH,
)

print("Candidate configs for pure test:", candidate_configs_for_pure_test_df.shape)
print("Saved:", CANDIDATE_CONFIGS_FOR_PURE_TEST_PATH)

display(candidate_configs_for_pure_test_df["matrix_family"].value_counts(dropna=False))
display(candidate_configs_for_pure_test_df["candidate_source"].value_counts(dropna=False))

display(
    candidate_configs_for_pure_test_df[
        [
            col for col in [
                "selected_config_id",
                "candidate_source",
                "selection_strategy",
                "matrix_family",
                "training_matrix_id",
                "model_family",
                "matrix_method",
                "preprocessing",
                "selected_rule_name",
                "n_components",
                "alpha",
                "object_threshold",
                "three_way_lower_threshold",
                "three_way_upper_threshold",
                "validation_fn_rate",
                "validation_fp_rate",
                "validation_3way_target_miss_rate",
                "validation_3way_uncertain_rate",
            ]
            if col in candidate_configs_for_pure_test_df.columns
        ]
    ].head(80)
)
# Out:
# Candidate configs for pure test: (31, 101)
# Saved: C:\Users\alixg\OneDrive - Université Paris-Dauphine\hsi_nuts\results\04B2_optuna_challenge_non_noisy_all\candidate_configs_for_pure_test.parquet
# matrix_family
# object_matrix    20
# pixel_matrix     11
# Name: count, dtype: int64
# candidate_source
# 04B_grid_robustness      18
# 04B2_optuna_challenge    13
# Name: count, dtype: int64
#            selected_config_id       candidate_source  \
# 0   optuna_object_matrix_0149  04B2_optuna_challenge
# 1   optuna_object_matrix_0081  04B2_optuna_challenge
# 2   optuna_object_matrix_0148  04B2_optuna_challenge
# 3   optuna_object_matrix_0184  04B2_optuna_challenge
# 4   optuna_object_matrix_0152  04B2_optuna_challenge
# 5   optuna_object_matrix_0157  04B2_optuna_challenge
# 6   optuna_object_matrix_0105  04B2_optuna_challenge
# 7   optuna_object_matrix_0121  04B2_optuna_challenge
# 8      04A_object_matrix_0001    04B_grid_robustness
# 9      04A_object_matrix_0002    04B_grid_robustness
# 10     04A_object_matrix_0003    04B_grid_robustness
# 11     04A_object_matrix_0004    04B_grid_robustness
# 12     04A_object_matrix_0005    04B_grid_robustness
# 13     04A_object_matrix_0006    04B_grid_robustness
# 14     04A_object_matrix_0007    04B_grid_robustness
# 15     04A_object_matrix_0008    04B_grid_robustness
# 16     04A_object_matrix_0009    04B_grid_robustness
# 17     04A_object_matrix_0010    04B_grid_robustness
# 18     04A_object_matrix_0012    04B_grid_robustness
# 19     04A_object_matrix_0015    04B_grid_robustness
# 20   optuna_pixel_matrix_0111  04B2_optuna_challenge
# 21   optuna_pixel_matrix_0285  04B2_optuna_challenge
# 22   optuna_pixel_matrix_0083  04B2_optuna_challenge
# 23   optuna_pixel_matrix_0257  04B2_optuna_challenge
# 24   optuna_pixel_matrix_0273  04B2_optuna_challenge
# 25      04A_pixel_matrix_0001    04B_grid_robustness
# 26      04A_pixel_matrix_0003    04B_grid_robustness
# 27      04A_pixel_matrix_0002    04B_grid_robustness
# 28      04A_pixel_matrix_0004    04B_grid_robustness
# 29      04A_pixel_matrix_0005    04B_grid_robustness
# 30      04A_pixel_matrix_0006    04B_grid_robustness
#
#                                    selection_strategy  matrix_family  \
# 0          04B2_optuna_binary_pareto__3way_calibrated  object_matrix
# 1          04B2_optuna_binary_pareto__3way_calibrated  object_matrix
# 2          04B2_optuna_binary_pareto__3way_calibrated  object_matrix
# 3          04B2_optuna_binary_pareto__3way_calibrated  object_matrix
# 4          04B2_optuna_binary_pareto__3way_calibrated  object_matrix
# 5          04B2_optuna_binary_pareto__3way_calibrated  object_matrix
# 6          04B2_optuna_binary_pareto__3way_calibrated  object_matrix
# 7          04B2_optuna_binary_pareto__3way_calibrated  object_matrix
# 8   04A_grid_rule_variant_universe__04B_robust_pareto  object_matrix
# 9   04A_grid_rule_variant_universe__04B_robust_pareto  object_matrix
# 10  04A_grid_rule_variant_universe__04B_robust_pareto  object_matrix
# 11  04A_grid_rule_variant_universe__04B_robust_pareto  object_matrix
# 12  04A_grid_rule_variant_universe__04B_robust_pareto  object_matrix
# 13  04A_grid_rule_variant_universe__04B_robust_pareto  object_matrix
# 14  04A_grid_rule_variant_universe__04B_robust_pareto  object_matrix
# 15  04A_grid_rule_variant_universe__04B_robust_pareto  object_matrix
# 16  04A_grid_rule_variant_universe__04B_robust_pareto  object_matrix
# 17  04A_grid_rule_variant_universe__04B_robust_pareto  object_matrix
# 18  04A_grid_rule_variant_universe__04B_robust_pareto  object_matrix
# 19  04A_grid_rule_variant_universe__04B_robust_pareto  object_matrix
# 20         04B2_optuna_binary_pareto__3way_calibrated   pixel_matrix
# 21         04B2_optuna_binary_pareto__3way_calibrated   pixel_matrix
# 22         04B2_optuna_binary_pareto__3way_calibrated   pixel_matrix
# 23         04B2_optuna_binary_pareto__3way_calibrated   pixel_matrix
# 24         04B2_optuna_binary_pareto__3way_calibrated   pixel_matrix
# 25  04A_grid_rule_variant_universe__04B_robust_pareto   pixel_matrix
# 26  04A_grid_rule_variant_universe__04B_robust_pareto   pixel_matrix
# 27  04A_grid_rule_variant_universe__04B_robust_pareto   pixel_matrix
# 28  04A_grid_rule_variant_universe__04B_robust_pareto   pixel_matrix
# 29  04A_grid_rule_variant_universe__04B_robust_pareto   pixel_matrix
# 30  04A_grid_rule_variant_universe__04B_robust_pareto   pixel_matrix
#
#            training_matrix_id       model_family    matrix_method  \
# 0               object_median  rule_variant_grid    object_median
# 1               object_median  rule_variant_grid    object_median
# 2               object_median  rule_variant_grid    object_median
# 3               object_median  rule_variant_grid    object_median
# 4               object_median  rule_variant_grid    object_median
# 5               object_median  rule_variant_grid    object_median
# 6                 object_mean  rule_variant_grid      object_mean
# 7                 object_mean  rule_variant_grid      object_mean
# 8                 object_mean  empirical_cv_rule      object_mean
# 9               object_median  empirical_cv_rule    object_median
# 10              object_median  empirical_cv_rule    object_median
# 11              object_median  empirical_cv_rule    object_median
# 12              object_median  empirical_cv_rule    object_median
# 13              object_median  empirical_cv_rule    object_median
# 14              object_median  empirical_cv_rule    object_median
# 15                object_mean  empirical_cv_rule      object_mean
# 16                object_mean  empirical_cv_rule      object_mean
# 17                object_mean  empirical_cv_rule      object_mean
# 18              object_median  empirical_cv_rule    object_median
# 19              object_median  empirical_cv_rule    object_median
# 20            balanced_pixels  rule_variant_grid  balanced_pixels
# 21            balanced_pixels  rule_variant_grid  balanced_pixels
# 22            balanced_pixels  rule_variant_grid  balanced_pixels
# 23            balanced_pixels  rule_variant_grid  balanced_pixels
# 24            balanced_pixels  rule_variant_grid  balanced_pixels
# 25  balanced_pixel_random_m40  empirical_cv_rule  balanced_pixels
# 26  balanced_pixel_random_m40  empirical_cv_rule  balanced_pixels
# 27  balanced_pixel_center_m40  empirical_cv_rule  balanced_pixels
# 28  balanced_pixel_random_m40  empirical_cv_rule  balanced_pixels
# 29  balanced_pixel_random_m40  empirical_cv_rule  balanced_pixels
# 30  balanced_pixel_random_m40  empirical_cv_rule  balanced_pixels
#
#                preprocessing        selected_rule_name  n_components  alpha  \
# 0                  sg_smooth   alternative_chi2_emp_cv             5   0.01
# 1                  sg_smooth        data_driven_emp_cv             5   0.01
# 2                  sg_smooth  alternative_empHQ_fixed2             5   0.01
# 3       absorbance_sg_smooth             simple_emp_cv             8   0.01
# 4           absorbance_sg_d2  alternative_empHQ_emp_cv             7   0.01
# 5                  sg_smooth       combined_index_chi2             3   0.01
# 6              snv_sg_smooth  alternative_empHQ_fixed2             3   0.01
# 7              snv_sg_smooth  alternative_empHQ_fixed2             3   0.01
# 8       absorbance_sg_smooth        data_driven_emp_cv          <NA>   0.01
# 9           absorbance_sg_d2        data_driven_emp_cv          <NA>   0.01
# 10          absorbance_sg_d2        data_driven_emp_cv          <NA>   0.01
# 11          absorbance_sg_d2             simple_emp_cv          <NA>   0.01
# 12          absorbance_sg_d2             simple_emp_cv          <NA>   0.01
# 13                       raw   alternative_chi2_emp_cv          <NA>   0.01
# 14                       raw        data_driven_emp_cv          <NA>   0.01
# 15                 sg_smooth        data_driven_emp_cv          <NA>   0.01
# 16                 sg_smooth             simple_emp_cv          <NA>   0.01
# 17                 sg_smooth        data_driven_emp_cv          <NA>   0.01
# 18             snv_sg_smooth   alternative_chi2_fixed2          <NA>   0.01
# 19             snv_sg_smooth          data_driven_chi2          <NA>   0.01
# 20      absorbance_sg_smooth          data_driven_chi2             7   0.01
# 21      absorbance_sg_smooth          data_driven_chi2             7   0.01
# 22                 sg_smooth               simple_chi2             6   0.05
# 23  absorbance_snv_sg_smooth               simple_chi2             6   0.05
# 24          absorbance_sg_d2               simple_chi2            10   0.05
# 25      absorbance_sg_smooth               simple_chi2          <NA>   0.01
# 26      absorbance_snv_sg_d1          data_driven_chi2          <NA>   0.01
# 27      absorbance_sg_smooth             simple_emp_cv          <NA>   0.05
# 28      absorbance_sg_smooth               simple_chi2          <NA>   0.01
# 29  absorbance_snv_sg_smooth               simple_chi2          <NA>   0.05
# 30      absorbance_snv_sg_d1          data_driven_chi2          <NA>   0.05
#
#     object_threshold  three_way_lower_threshold  three_way_upper_threshold  \
# 0               0.50                       0.50                       0.95
# 1               0.50                       0.50                       0.95
# 2               0.50                       0.50                       0.95
# 3               0.50                       0.30                       0.70
# 4               0.50                       0.25                       0.65
# 5               0.50                       0.05                       0.65
# 6               0.55                       0.15                       0.55
# 7               0.55                       0.15                       0.55
# 8               0.75                       0.05                       0.95
# 9               0.70                       0.55                       0.95
# 10              0.75                       0.55                       0.95
# 11              0.70                       0.55                       0.95
# 12              0.75                       0.55                       0.95
# 13              0.75                       0.30                       0.90
# 14              0.75                       0.35                       0.85
# 15              0.75                       0.40                       0.80
# 16              0.80                       0.45                       0.80
# 17              0.80                       0.40                       0.80
# 18              0.70                       0.20                       0.70
# 19              0.70                       0.15                       0.65
# 20              0.75                       0.60                       0.95
# 21              0.60                       0.60                       0.95
# 22              0.55                       0.30                       0.95
# 23              0.55                       0.40                       0.65
# 24              0.50                       0.05                       0.50
# 25              0.75                       0.55                       0.95
# 26              0.70                       0.60                       0.75
# 27              0.70                       0.55                       0.90
# 28              0.80                       0.55                       0.95
# 29              0.75                       0.50                       0.80
# 30              0.70                       0.50                       0.70
#
#     validation_fn_rate  validation_fp_rate  validation_3way_target_miss_rate  \
# 0             0.000000            0.927273                          0.000000
# 1             0.000000            0.927273                          0.000000
# 2             0.000000            0.927273                          0.000000
# 3             0.018868            0.527273                          0.000000
# 4             0.150943            0.418182                          0.000000
# 5             0.207547            0.400000                          0.000000
# 6             0.264151            0.000000                          0.000000
# 7             0.264151            0.000000                          0.000000
# 8             0.000000            0.945455                          0.000000
# 9             0.018868            0.781818                          0.000000
# 10            0.056604            0.745455                          0.000000
# 11            0.075472            0.672727                          0.000000
# 12            0.132075            0.600000                          0.000000
# 13            0.169811            0.581818                          0.000000
# 14            0.188679            0.563636                          0.000000
# 15            0.207547            0.381818                          0.000000
# 16            0.245283            0.309091                          0.000000
# 17            0.264151            0.272727                          0.000000
# 18            0.358491            0.127273                          0.000000
# 19            0.528302            0.000000                          0.000000
# 20            0.000000            0.200000                          0.000000
# 21            0.000000            0.200000                          0.000000
# 22            0.037736            0.181818                          0.000000
# 23            0.056604            0.036364                          0.000000
# 24            1.000000            0.000000                          0.132075
# 25            0.000000            0.109091                          0.000000
# 26            0.056604            0.072727                          0.000000
# 27            0.056604            0.072727                          0.000000
# 28            0.094340            0.054545                          0.000000
# 29            0.113208            0.018182                          0.000000
# 30            0.132075            0.000000                          0.000000
#
#     validation_3way_uncertain_rate
# 0                         0.509259
# 1                         0.546296
# 2                         0.601852
# 3                         0.564815
# 4                         0.500000
# 5                         0.555556
# 6                         0.416667
# 7                         0.416667
# 8                         0.435185
# 9                         0.712963
# 10                        0.712963
# 11                        0.814815
# 12                        0.814815
# 13                        0.546296
# 14                        0.500000
# 15                        0.481481
# 16                        0.453704
# 17                        0.481481
# 18                        0.500000
# 19                        0.564815
# 20                        0.351852
# 21                        0.407407
# 22                        0.518519
# 23                        0.074074
# 24                        0.537037
# 25                        0.314815
# 26                        0.166667
# 27                        0.287037
# 28                        0.314815
# 29                        0.157407
# 30                        0.148148

# %%
optuna_challenge_protocol_df = pd.DataFrame([{
    "db_h5_path": str(DB_H5_PATH),
    "results_dir": str(RESULTS_DIR),

    "wavelength_mode": WAVELENGTH_MODE,
    "use_wavelength_window": bool(USE_WAVELENGTH_WINDOW),
    "results_tag": RESULTS_TAG,
    "window_min_nm": WINDOW_MIN_NM if USE_WAVELENGTH_WINDOW else np.nan,
    "window_max_nm": WINDOW_MAX_NM if USE_WAVELENGTH_WINDOW else np.nan,
    "n_active_bands": int(len(wavelengths)),

    "target_class": TARGET_CLASS,
    "non_target_label": NON_TARGET_LABEL,
    "reference_classes_json": json.dumps(list(REFERENCE_CLASSES)),

    "train_filters_json": json.dumps(TRAIN_FILTERS, default=str),
    "validation_filters_json": json.dumps(VALIDATION_FILTERS, default=str),

    "pca_selected_preprocessings_path": str(PCA_SELECTED_PREPROCESSINGS_PATH),
    "grid_selected_candidates_path": str(GRID_SELECTED_CANDIDATES_PATH),
    "robust_candidate_configs_path": str(ROBUST_CANDIDATE_CONFIGS_PATH),

    "optuna_storage_object_path": str(OPTUNA_STORAGE_OBJECT_PATH),
    "optuna_storage_pixel_path": str(OPTUNA_STORAGE_PIXEL_PATH),
    "run_optuna": bool(RUN_OPTUNA),
    "load_existing_study": bool(LOAD_EXISTING_STUDY),
    "n_trials_object_matrix": int(OPTUNA_N_TRIALS_PER_FAMILY["object_matrix"]),
    "n_trials_pixel_matrix": int(OPTUNA_N_TRIALS_PER_FAMILY["pixel_matrix"]),
    "timeout": OPTUNA_TIMEOUT,
    "n_jobs": int(OPTUNA_N_JOBS),
    "random_state": int(RANDOM_STATE),

    "matrix_family_spaces_json": json.dumps(
        {
            fam: {
                key: str(value)
                for key, value in space.items()
                if key != "storage_path"
            }
            for fam, space in OPTUNA_MATRIX_FAMILY_SPACES.items()
        },
        default=str,
    ),

    "rule_variants_json": json.dumps(OPTUNA_RULE_VARIANTS),
    "n_components_choices_json": json.dumps(OPTUNA_N_COMPONENTS_CHOICES),
    "alpha_choices_json": json.dumps(OPTUNA_ALPHA_CHOICES),
    "object_thresholds_json": json.dumps([float(v) for v in OPTUNA_OBJECT_THRESHOLDS]),
    "objective_seeds_json": json.dumps(OPTUNA_OBJECTIVE_SEEDS),

    "m_choices_json": json.dumps(OPTUNA_M_CHOICES),
    "balanced_pixel_strategy_choices_json": json.dumps(OPTUNA_BALANCED_PIXEL_STRATEGY_CHOICES),
    "sg_window_choices_json": json.dumps(OPTUNA_SG_WINDOW_CHOICES),
    "sg_polyorder_choices_json": json.dumps(OPTUNA_SG_POLYORDER_CHOICES),
    "position_dilation_radius_choices_json": json.dumps(OPTUNA_POSITION_DILATION_RADIUS_CHOICES),

    "preprocessing_configs_json": json.dumps(
        {
            family: {name: list(steps) for name, steps in configs.items()}
            for family, configs in PREPROCESSING_CONFIGS.items()
        },
        default=str,
    ),

    "n_trials_total": int(len(optuna_trials_df)),
    "n_trials_completed": int(len(optuna_completed_trials_df)),
    "n_optuna_pareto_candidates": int(len(optuna_pareto_candidates_df)),
    "n_optuna_challengers": int(len(optuna_challengers_df)),
    "n_candidate_configs_for_pure_test": int(len(candidate_configs_for_pure_test_df)),

    "optuna_trials_all_path": str(OPTUNA_ALL_TRIALS_PATH),
    "optuna_trials_object_path": str(OPTUNA_TRIALS_OBJECT_PATH),
    "optuna_trials_pixel_path": str(OPTUNA_TRIALS_PIXEL_PATH),
    "optuna_pareto_candidates_path": str(OPTUNA_PARETO_CANDIDATES_PATH),
    "optuna_validation_refit_metrics_path": str(OPTUNA_VALIDATION_REFIT_METRICS_PATH),
    "optuna_validation_3way_metrics_path": str(OPTUNA_VALIDATION_3WAY_METRICS_PATH),
    "optuna_challengers_for_04C_path": str(OPTUNA_CHALLENGERS_FOR_04C_PATH),
    "candidate_configs_for_pure_test_path": str(CANDIDATE_CONFIGS_FOR_PURE_TEST_PATH),
}])

save_parquet(
    optuna_challenge_protocol_df,
    OPTUNA_CHALLENGE_PROTOCOL_PATH,
)

print("Saved Optuna challenge protocol:")
print(OPTUNA_CHALLENGE_PROTOCOL_PATH)

display(optuna_challenge_protocol_df)
# Out:
# Saved Optuna challenge protocol:
# C:\Users\alixg\OneDrive - Université Paris-Dauphine\hsi_nuts\results\04B2_optuna_challenge_non_noisy_all\optuna_challenge_protocol.parquet
#                                           db_h5_path  \
# 0  C:\Users\alixg\OneDrive - Université Paris-Dau...
#
#                                          results_dir wavelength_mode  \
# 0  C:\Users\alixg\OneDrive - Université Paris-Dau...   non_noisy_all
#
#    use_wavelength_window    results_tag  window_min_nm  window_max_nm  \
# 0                  False  non_noisy_all            NaN            NaN
#
#    n_active_bands target_class non_target_label reference_classes_json  \
# 0              63       peanut           almond   ["almond", "peanut"]
#
#                                   train_filters_json  \
# 0  {"sample_kind": ["pure"], "object_nut_type": [...
#
#                              validation_filters_json  \
# 0  {"sample_kind": ["pure"], "object_nut_type": [...
#
#                     pca_selected_preprocessings_path  \
# 0  C:\Users\alixg\OneDrive - Université Paris-Dau...
#
#                        grid_selected_candidates_path  \
# 0  C:\Users\alixg\OneDrive - Université Paris-Dau...
#
#                        robust_candidate_configs_path  \
# 0  C:\Users\alixg\OneDrive - Université Paris-Dau...
#
#                           optuna_storage_object_path  \
# 0  C:\Users\alixg\OneDrive - Université Paris-Dau...
#
#                            optuna_storage_pixel_path  run_optuna  \
# 0  C:\Users\alixg\OneDrive - Université Paris-Dau...        True
#
#    load_existing_study  n_trials_object_matrix  n_trials_pixel_matrix timeout  \
# 0                False                     200                    300    None
#
#    n_jobs  random_state                          matrix_family_spaces_json  \
# 0       1            42  {"object_matrix": {"matrix_methods": "['object...
#
#                                   rule_variants_json  \
# 0  ["simple_chi2", "simple_emp_cv", "alternative_...
#
#         n_components_choices_json alpha_choices_json  \
# 0  [3, 4, 5, 6, 7, 8, 10, 11, 12]       [0.05, 0.01]
#
#                               object_thresholds_json objective_seeds_json  \
# 0  [0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0...            [0, 1, 2]
#
#      m_choices_json balanced_pixel_strategy_choices_json  \
# 0  [20, 40, 60, 80]                 ["random", "center"]
#
#   sg_window_choices_json sg_polyorder_choices_json  \
# 0     [7, 9, 11, 13, 15]                       [2]
#
#   position_dilation_radius_choices_json  \
# 0                          [2, 3, 4, 5]
#
#                           preprocessing_configs_json  n_trials_total  \
# 0  {"absorbance_sg_smooth": ["absorbance", "sg_sm...             500
#
#    n_trials_completed  n_optuna_pareto_candidates  n_optuna_challengers  \
# 0                 500                          21                    21
#
#    n_candidate_configs_for_pure_test  \
# 0                                 31
#
#                               optuna_trials_all_path  \
# 0  C:\Users\alixg\OneDrive - Université Paris-Dau...
#
#                            optuna_trials_object_path  \
# 0  C:\Users\alixg\OneDrive - Université Paris-Dau...
#
#                             optuna_trials_pixel_path  \
# 0  C:\Users\alixg\OneDrive - Université Paris-Dau...
#
#                        optuna_pareto_candidates_path  \
# 0  C:\Users\alixg\OneDrive - Université Paris-Dau...
#
#                 optuna_validation_refit_metrics_path  \
# 0  C:\Users\alixg\OneDrive - Université Paris-Dau...
#
#                  optuna_validation_3way_metrics_path  \
# 0  C:\Users\alixg\OneDrive - Université Paris-Dau...
#
#                      optuna_challengers_for_04C_path  \
# 0  C:\Users\alixg\OneDrive - Université Paris-Dau...
#
#                 candidate_configs_for_pure_test_path
# 0  C:\Users\alixg\OneDrive - Université Paris-Dau...

# %%
print("04B2_optuna_challenge_optional.ipynb completed.")
print()
print("Essential outputs:")
print(" -", OPTUNA_TRIALS_OBJECT_PATH)
print(" -", OPTUNA_TRIALS_PIXEL_PATH)
print(" -", OPTUNA_ALL_TRIALS_PATH)
print(" -", OPTUNA_PARETO_CANDIDATES_PATH)
print(" -", OPTUNA_VALIDATION_REFIT_METRICS_PATH)
print(" -", OPTUNA_VALIDATION_3WAY_METRICS_PATH)
print(" -", OPTUNA_CHALLENGERS_FOR_04C_PATH)
print(" -", CANDIDATE_CONFIGS_FOR_PURE_TEST_PATH)
print(" -", OPTUNA_CHALLENGE_PROTOCOL_PATH)

print()
print("Summary:")
print(f" - Total Optuna trials: {len(optuna_trials_df)}")
print(f" - Completed Optuna trials: {len(optuna_completed_trials_df)}")
print(f" - Optuna Pareto candidates: {len(optuna_pareto_candidates_df)}")
print(f" - Optuna challengers for 04C: {len(optuna_challengers_df)}")
print(f" - Candidate configs for pure test: {len(candidate_configs_for_pure_test_df)}")
print()
print("Next notebook:")
print("04C_simca_pure_test_evaluation.ipynb")
# Out:
# 04B2_optuna_challenge_optional.ipynb completed.
#
# Essential outputs:
#  - C:\Users\alixg\OneDrive - Université Paris-Dauphine\hsi_nuts\results\04B2_optuna_challenge_non_noisy_all\optuna_trials_object_matrix.parquet
#  - C:\Users\alixg\OneDrive - Université Paris-Dauphine\hsi_nuts\results\04B2_optuna_challenge_non_noisy_all\optuna_trials_pixel_matrix.parquet
#  - C:\Users\alixg\OneDrive - Université Paris-Dauphine\hsi_nuts\results\04B2_optuna_challenge_non_noisy_all\optuna_trials_all_families.parquet
#  - C:\Users\alixg\OneDrive - Université Paris-Dauphine\hsi_nuts\results\04B2_optuna_challenge_non_noisy_all\optuna_pareto_candidates.parquet
#  - C:\Users\alixg\OneDrive - Université Paris-Dauphine\hsi_nuts\results\04B2_optuna_challenge_non_noisy_all\optuna_validation_refit_metrics.parquet
#  - C:\Users\alixg\OneDrive - Université Paris-Dauphine\hsi_nuts\results\04B2_optuna_challenge_non_noisy_all\optuna_validation_3way_metrics.parquet
#  - C:\Users\alixg\OneDrive - Université Paris-Dauphine\hsi_nuts\results\04B2_optuna_challenge_non_noisy_all\optuna_challengers_for_04C.parquet
#  - C:\Users\alixg\OneDrive - Université Paris-Dauphine\hsi_nuts\results\04B2_optuna_challenge_non_noisy_all\candidate_configs_for_pure_test.parquet
#  - C:\Users\alixg\OneDrive - Université Paris-Dauphine\hsi_nuts\results\04B2_optuna_challenge_non_noisy_all\optuna_challenge_protocol.parquet
#
# Summary:
#  - Total Optuna trials: 500
#  - Completed Optuna trials: 500
#  - Optuna Pareto candidates: 21
#  - Optuna challengers for 04C: 21
#  - Candidate configs for pure test: 31
#
# Next notebook:
# 04C_simca_pure_test_evaluation.ipynb
